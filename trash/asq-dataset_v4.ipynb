# %% [markdown]
# # Dataset for Asquire experiments
#
# > prepare master_asquire_corpus.csv file that contains informant of entire pnoi-corpus

# %%
import pandas as pd
import numpy as np
import shutil
import glob
import json
import os

mkdir = lambda p: 0 if os.path.exists(p) else (os.makedirs(p), 1)[1]

# %% [markdown]
# ## STATE VARIABLES

# %%
IS_DRY_RUN = False
IS_DUMMY_PATH = False

# %% [markdown]
# ## PATHS

# %%
DATA_PATH = "DATA_DUMMY" if IS_DUMMY_PATH else "report/audio_files_v5"

REPORT_FOLDER = "report"; mkdir(REPORT_FOLDER)
# Out:
# 0

# %% [markdown]
# ## Dataset Class

# %%
class DataStaticInfo:

    VER = "*"
    SEP = "_"
    META_SEP = "-"
    EXT_SEP = "."
    ANOT_LABELS = ['cc', 'ss', 'aa', 'yy', 'ee', 'ii', 'xx', 'zz', 'uu', 'oo', 'ii-n']

    fkeys = {
        "APP_CODE": "app_code", # 0
        "SID":"sub_id", # 1
        "FCLASS": "file_class", # 2
        "FCIDX": "file_xindex", # 3
        "SCORE": "score", # 4
        "FFMT": "file_format", # 5
        "FNAME": "file_name", # 6
        "FPATH": "file_path", # 7
        "FMATCH": "file_match" # 8
    }

# %%
class DataExtractFiles(DataStaticInfo):

    ALL_FILES_DF: pd.DataFrame
    

    def __init__(self, path: str, ver="*") -> None:
        self.VER = ver

        all_files = glob.glob(f"{path}/*/{ver}")

        self.ALL_FILES_DF = self.make_files_df(all_files)


    def file_dict(self, fpath: str) -> dict:
        sub_path, fname = os.path.split(fpath)
        _, sub_id = os.path.split(sub_path)

        match_key = fname.split(self.EXT_SEP)[0]

        fitems = fname.replace(self.EXT_SEP, self.SEP, 1).split(self.SEP) 

        # fitems[1] = sub_id
        fitems += [fname, fpath, match_key]
        
        fdict = dict(zip(self.fkeys.values(), fitems))
        return fdict
    
    def make_files_df(self, all_files: list) -> pd.DataFrame:
        files = [self.file_dict(fp) for fp in all_files]
        return pd.DataFrame(files)
    
    def get_file_extention(self) -> str:
        return self.ALL_FILES_DF[self.fkeys["FFMT"]].unique()
    
    def get_subject_list(self) -> list:
        return self.ALL_FILES_DF[self.fkeys["SID"]].unique()
    
asqdata_files = DataExtractFiles(DATA_PATH, ver="*")

# %%
asqdata_files.get_subject_list().__len__()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 asqdata_files.get_subject_list().__len__()
#
# Cell In[6], line 36, in DataExtractFiles.get_subject_list(self)
#      35 def get_subject_list(self) -> list:
# ---> 36     return self.ALL_FILES_DF[self.fkeys["SID"]].unique()
#
# File ~/jeevan/asquire-etl/env_etl/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/jeevan/asquire-etl/env_etl/lib/python3.11/site-packages/pandas/core/indexes/range.py:349, in RangeIndex.get_loc(self, key)
#     347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
# --> 349     raise KeyError(key)
#     350 self._check_indexing_error(key)
#     351 raise KeyError(key)
#
# KeyError: 'sub_id'

# %%
print(len(asqdata_files.ALL_FILES_DF), "files")
asqdata_files.ALL_FILES_DF
# Out:
# 3135 files
#                    app_code              sub_id file_class file_xindex score  \
# 0        webapp-asquire-mox      anish-02df6c90      cough           1    NA
# 1        webapp-asquire-mox      anish-02df6c90     breath           0    NA
# 2        webapp-asquire-mox      anish-02df6c90     breath           0    NA
# 3        webapp-asquire-mox      anish-02df6c90         zz           4    NA
# 4        webapp-asquire-mox      anish-02df6c90      cough           1    NA
# ...                     ...                 ...        ...         ...   ...
# 3130     webapp-asquire-mox  shivendra-49fd0914         aa           4     2
# 3131     webapp-asquire-mox  shivendra-49fd0914         aa           4     2
# 3132     webapp-asquire-mox  shivendra-49fd0914     breath           2     0
# 3133     webapp-asquire-mox  shivendra-49fd0914     breath           2     0
# 3134  webapp-asquire-mox-na  shivendra-49fd0914  meta-data          na    na
#
#      file_format                                          file_name  \
# 0            wav   webapp-asquire-mox_anish-02df6c90_cough_1_NA.wav
# 1            txt  webapp-asquire-mox_anish-02df6c90_breath_0_NA.txt
# 2            wav  webapp-asquire-mox_anish-02df6c90_breath_0_NA.wav
# 3            txt      webapp-asquire-mox_anish-02df6c90_zz_4_NA.txt
# 4            txt   webapp-asquire-mox_anish-02df6c90_cough_1_NA.txt
# ...          ...                                                ...
# 3130         txt   webapp-asquire-mox_shivendra-49fd0914_aa_4_2.txt
# 3131         wav   webapp-asquire-mox_shivendra-49fd0914_aa_4_2.wav
# 3132         txt  webapp-asquire-mox_shivendra-49fd0914_breath_2...
# 3133         wav  webapp-asquire-mox_shivendra-49fd0914_breath_2...
# 3134        json  webapp-asquire-mox-na_shivendra-49fd0914_meta-...
#
#                                               file_path  \
# 0     report/audio_files_v5/anish-02df6c90/webapp-as...
# 1     report/audio_files_v5/anish-02df6c90/webapp-as...
# 2     report/audio_files_v5/anish-02df6c90/webapp-as...
# 3     report/audio_files_v5/anish-02df6c90/webapp-as...
# 4     report/audio_files_v5/anish-02df6c90/webapp-as...
# ...                                                 ...
# 3130  report/audio_files_v5/shivendra-49fd0914/webap...
# 3131  report/audio_files_v5/shivendra-49fd0914/webap...
# 3132  report/audio_files_v5/shivendra-49fd0914/webap...
# 3133  report/audio_files_v5/shivendra-49fd0914/webap...
# 3134  report/audio_files_v5/shivendra-49fd0914/webap...
#
#                                              file_match
# 0          webapp-asquire-mox_anish-02df6c90_cough_1_NA
# 1         webapp-asquire-mox_anish-02df6c90_breath_0_NA
# 2         webapp-asquire-mox_anish-02df6c90_breath_0_NA
# 3             webapp-asquire-mox_anish-02df6c90_zz_4_NA
# 4          webapp-asquire-mox_anish-02df6c90_cough_1_NA
# ...                                                 ...
# 3130       webapp-asquire-mox_shivendra-49fd0914_aa_4_2
# 3131       webapp-asquire-mox_shivendra-49fd0914_aa_4_2
# 3132   webapp-asquire-mox_shivendra-49fd0914_breath_2_0
# 3133   webapp-asquire-mox_shivendra-49fd0914_breath_2_0
# 3134  webapp-asquire-mox-na_shivendra-49fd0914_meta-...
#
# [3135 rows x 9 columns]

# %%
asqdata_files.get_file_extention()
# Out:
# array(['wav', 'txt', 'json'], dtype=object)

# %%
class DataSourceFiles(DataStaticInfo):

    src_data_fname_regx = r"^webapp-asquire-(?!.*\.meta\.).+\.(wav|json|)$"

    ALL_FILES_DF: pd.DataFrame
    SOURCE_FILES_DF: pd.DataFrame

    def __init__(self, all_file_df: pd.DataFrame) -> None:
        self.ALL_FILES_DF = all_file_df

        self.SOURCE_FILES_DF = self.pair_src_anot_files()

    def make_source_files_df(self) -> pd.DataFrame:
        filt = self.ALL_FILES_DF.loc[:, self.fkeys["FNAME"]].str.match(self.src_data_fname_regx)

        df = self.ALL_FILES_DF[filt]
        return df
    
    def anot_path_join(self, p: pd.Series) -> str:
        fpath = os.path.join(os.path.split(p[self.fkeys['FPATH']])[0], p[f"anot--{self.fkeys['FNAME']}"])

        return fpath if os.path.exists(fpath) else False
    
    def pair_src_anot_files(self) -> pd.DataFrame:
        anot_format_mapping = { self.fkeys["FFMT"]: {'wav': 'txt', "json": "meta.json"} }

        source_files_DF = self.make_source_files_df()
    
        anot_file_format_DF = source_files_DF.replace(anot_format_mapping) # anotation file extension

        # rename file_format to anot--file-format
        anot_fmt_column = f"anot--{self.fkeys['FFMT']}"
        anot_file_format_DF.rename(columns={self.fkeys["FFMT"]: anot_fmt_column}, inplace=True)
        anot_file_format_DF = anot_file_format_DF[[anot_fmt_column, self.fkeys["FMATCH"]]]
       
        
        # mergr source and anotation files
        src_data_files_DF = pd.merge(source_files_DF, anot_file_format_DF, on=self.fkeys["FMATCH"], how="left")
        anot_fname_column = f"anot--{self.fkeys['FNAME']}"

        src_data_files_DF[anot_fname_column] = src_data_files_DF[self.fkeys["FMATCH"]] + '.' + src_data_files_DF[anot_fmt_column]


        anot_fpath_column = f"anot--{self.fkeys['FPATH']}"
        anote_filepath_df = src_data_files_DF.apply(self.anot_path_join, axis=1).to_frame(name=anot_fpath_column)

        src_data_files_DF = pd.concat([src_data_files_DF, anote_filepath_df], axis=1)

        return src_data_files_DF

asqdata_source_files = DataSourceFiles(asqdata_files.ALL_FILES_DF)
asqdata_source_files.SOURCE_FILES_DF
# Out:
#                    app_code              sub_id file_class file_xindex score  \
# 0        webapp-asquire-mox      anish-02df6c90      cough           1    NA
# 1        webapp-asquire-mox      anish-02df6c90     breath           0    NA
# 2        webapp-asquire-mox      anish-02df6c90         ss           5    NA
# 3        webapp-asquire-mox      anish-02df6c90        yee           6    NA
# 4     webapp-asquire-mox-na      anish-02df6c90  meta-data          na    na
# ...                     ...                 ...        ...         ...   ...
# 1664     webapp-asquire-mox   srinivas-b89febe6     breath           5    NA
# 1665     webapp-asquire-mox   srinivas-b89febe6         aa           2    NA
# 1666     webapp-asquire-mox  shivendra-49fd0914         aa           4     2
# 1667     webapp-asquire-mox  shivendra-49fd0914     breath           2     0
# 1668  webapp-asquire-mox-na  shivendra-49fd0914  meta-data          na    na
#
#      file_format                                          file_name  \
# 0            wav   webapp-asquire-mox_anish-02df6c90_cough_1_NA.wav
# 1            wav  webapp-asquire-mox_anish-02df6c90_breath_0_NA.wav
# 2            wav      webapp-asquire-mox_anish-02df6c90_ss_5_NA.wav
# 3            wav     webapp-asquire-mox_anish-02df6c90_yee_6_NA.wav
# 4           json  webapp-asquire-mox-na_anish-02df6c90_meta-data...
# ...          ...                                                ...
# 1664         wav  webapp-asquire-mox_srinivas-b89febe6_breath_5_...
# 1665         wav   webapp-asquire-mox_srinivas-b89febe6_aa_2_NA.wav
# 1666         wav   webapp-asquire-mox_shivendra-49fd0914_aa_4_2.wav
# 1667         wav  webapp-asquire-mox_shivendra-49fd0914_breath_2...
# 1668        json  webapp-asquire-mox-na_shivendra-49fd0914_meta-...
#
#                                               file_path  \
# 0     report/audio_files_v5/anish-02df6c90/webapp-as...
# 1     report/audio_files_v5/anish-02df6c90/webapp-as...
# 2     report/audio_files_v5/anish-02df6c90/webapp-as...
# 3     report/audio_files_v5/anish-02df6c90/webapp-as...
# 4     report/audio_files_v5/anish-02df6c90/webapp-as...
# ...                                                 ...
# 1664  report/audio_files_v5/srinivas-b89febe6/webapp...
# 1665  report/audio_files_v5/srinivas-b89febe6/webapp...
# 1666  report/audio_files_v5/shivendra-49fd0914/webap...
# 1667  report/audio_files_v5/shivendra-49fd0914/webap...
# 1668  report/audio_files_v5/shivendra-49fd0914/webap...
#
#                                              file_match anot--file_format  \
# 0          webapp-asquire-mox_anish-02df6c90_cough_1_NA               txt
# 1         webapp-asquire-mox_anish-02df6c90_breath_0_NA               txt
# 2             webapp-asquire-mox_anish-02df6c90_ss_5_NA               txt
# 3            webapp-asquire-mox_anish-02df6c90_yee_6_NA               txt
# 4     webapp-asquire-mox-na_anish-02df6c90_meta-data...         meta.json
# ...                                                 ...               ...
# 1664   webapp-asquire-mox_srinivas-b89febe6_breath_5_NA               txt
# 1665       webapp-asquire-mox_srinivas-b89febe6_aa_2_NA               txt
# 1666       webapp-asquire-mox_shivendra-49fd0914_aa_4_2               txt
# 1667   webapp-asquire-mox_shivendra-49fd0914_breath_2_0               txt
# 1668  webapp-asquire-mox-na_shivendra-49fd0914_meta-...         meta.json
#
#                                         anot--file_name  \
# 0      webapp-asquire-mox_anish-02df6c90_cough_1_NA.txt
# 1     webapp-asquire-mox_anish-02df6c90_breath_0_NA.txt
# 2         webapp-asquire-mox_anish-02df6c90_ss_5_NA.txt
# 3        webapp-asquire-mox_anish-02df6c90_yee_6_NA.txt
# 4     webapp-asquire-mox-na_anish-02df6c90_meta-data...
# ...                                                 ...
# 1664  webapp-asquire-mox_srinivas-b89febe6_breath_5_...
# 1665   webapp-asquire-mox_srinivas-b89febe6_aa_2_NA.txt
# 1666   webapp-asquire-mox_shivendra-49fd0914_aa_4_2.txt
# 1667  webapp-asquire-mox_shivendra-49fd0914_breath_2...
# 1668  webapp-asquire-mox-na_shivendra-49fd0914_meta-...
#
#                                         anot--file_path
# 0     report/audio_files_v5/anish-02df6c90/webapp-as...
# 1     report/audio_files_v5/anish-02df6c90/webapp-as...
# 2     report/audio_files_v5/anish-02df6c90/webapp-as...
# 3     report/audio_files_v5/anish-02df6c90/webapp-as...
# 4                                                 False
# ...                                                 ...
# 1664  report/audio_files_v5/srinivas-b89febe6/webapp...
# 1665  report/audio_files_v5/srinivas-b89febe6/webapp...
# 1666  report/audio_files_v5/shivendra-49fd0914/webap...
# 1667  report/audio_files_v5/shivendra-49fd0914/webap...
# 1668                                              False
#
# [1669 rows x 12 columns]

# %%
class ProcessMETAFiles(DataStaticInfo):

    SOURCE_FILES_DF: pd.DataFrame
    SOURCE_FILES_META_DF: pd.DataFrame
    
    def __init__(self, all_src_file_df: pd.DataFrame) -> None:
        self.SOURCE_FILES_DF = all_src_file_df
        
        self.SOURCE_FILES_META_DF = self.make_meta_df()

    def read_metadata(self, row):
        file_path = row[self.fkeys["FPATH"]]

        # file_info = { "file_path": file_path }

        with open(file_path, 'r') as f:
            print(f"./{file_path}")
            data = json.load(f)

            bio_data: dict = data["bio"] #| file_info

            bio_data[self.fkeys["SID"]] = data["userId"].replace("_", "-")
            # survey_data_q = data["survey"]["allQuestions"]
            survey_data_a = data["survey"]

            
            bio_data_dict = [{ "qn": k, "Q": f"{k}?", "A": v } for k, v in sorted(bio_data.items())]
            # survey_data_dict_q = [{ "qn": str(q["qno"]), "Q": q["question"] } for q in survey_data_q.values()]
            survey_data_dict = [{ "qn": str(q["qno"]), "Q": q["question"], "A": q["answer"] } for q in survey_data_a]
            # survey_data_q_DF = pd.DataFrame(survey_data_dict_q)
            survey_data_a_DF = pd.DataFrame(bio_data_dict + survey_data_dict)

            

            # survey_data_o_DF = survey_data_q_DF.merge(survey_data_a_DF, how="outer", on=["qn", "Q"])
            survey_data_o_DF = survey_data_a_DF #survey_data_q_DF.merge(survey_data_a_DF, how="outer", on=["qn", "Q"])
            survey_data_o_DF.fillna("-", inplace=True)

            nfile_path = file_path.replace(".json", ".meta.json")
            print(f"./{nfile_path}")
            survey_data_o_DF.set_index('qn').to_json(nfile_path, orient='index')

            return (bio_data, survey_data_o_DF)
        
    def make_meta_df(self) -> pd.DataFrame:
        filt = self.SOURCE_FILES_DF[self.fkeys["FCLASS"]] == "meta-data"
        src_META_data_DF = self.SOURCE_FILES_DF[filt]

        all_META_data_DF = pd.DataFrame([self.read_metadata(row)[0] for _, row in src_META_data_DF.iterrows()])

        src_data_files_DF = self.SOURCE_FILES_DF.copy()
        src_data_files_DF = src_data_files_DF.merge(all_META_data_DF, how="left", on=[self.fkeys["SID"]])

        return src_data_files_DF


asqdata_meta_files = ProcessMETAFiles(asqdata_source_files.SOURCE_FILES_DF)
asqdata_meta_files.make_meta_df() #.columns.to_list()
# Out:
# ./report/audio_files_v5/anish-02df6c90/webapp-asquire-mox-na_anish-02df6c90_meta-data_na_na.json
# ./report/audio_files_v5/anish-02df6c90/webapp-asquire-mox-na_anish-02df6c90_meta-data_na_na.meta.json
# ./report/audio_files_v5/ananyach-9a6a2c78/webapp-asquire-mox-na_ananyach-9a6a2c78_meta-data_na_na.json
# ./report/audio_files_v5/ananyach-9a6a2c78/webapp-asquire-mox-na_ananyach-9a6a2c78_meta-data_na_na.meta.json
# ./report/audio_files_v5/muqaddas-50022e79/webapp-asquire-mox-na_muqaddas-50022e79_meta-data_na_na.json
# ./report/audio_files_v5/muqaddas-50022e79/webapp-asquire-mox-na_muqaddas-50022e79_meta-data_na_na.meta.json
# ./report/audio_files_v5/vinay-56bb71de/webapp-asquire-mox-na_vinay-56bb71de_meta-data_na_na.json
# ./report/audio_files_v5/vinay-56bb71de/webapp-asquire-mox-na_vinay-56bb71de_meta-data_na_na.meta.json
# ./report/audio_files_v5/ramswaroop-8fd26b2a/webapp-asquire-mox-na_ramswaroop-8fd26b2a_meta-data_na_na.json
# ./report/audio_files_v5/ramswaroop-8fd26b2a/webapp-asquire-mox-na_ramswaroop-8fd26b2a_meta-data_na_na.meta.json
# ./report/audio_files_v5/nikhil-0e7b9f80/webapp-asquire-mox-na_nikhil-0e7b9f80_meta-data_na_na.json
# ./report/audio_files_v5/nikhil-0e7b9f80/webapp-asquire-mox-na_nikhil-0e7b9f80_meta-data_na_na.meta.json
# ./report/audio_files_v5/jayasurya-99f989e3/webapp-asquire-mox-na_jayasurya-99f989e3_meta-data_na_na.json
# ./report/audio_files_v5/jayasurya-99f989e3/webapp-asquire-mox-na_jayasurya-99f989e3_meta-data_na_na.meta.json
# ./report/audio_files_v5/bhargavee-70c0073e/webapp-asquire-mox-na_bhargavee-70c0073e_meta-data_na_na.json
# ./report/audio_files_v5/bhargavee-70c0073e/webapp-asquire-mox-na_bhargavee-70c0073e_meta-data_na_na.meta.json
# ./report/audio_files_v5/rukhsana-d7170e62/webapp-asquire-mox-na_rukhsana-d7170e62_meta-data_na_na.json
# ./report/audio_files_v5/rukhsana-d7170e62/webapp-asquire-mox-na_rukhsana-d7170e62_meta-data_na_na.meta.json
# ./report/audio_files_v5/pabin-288d0c22/webapp-asquire-mox-na_pabin-288d0c22_meta-data_na_na.json
# ./report/audio_files_v5/pabin-288d0c22/webapp-asquire-mox-na_pabin-288d0c22_meta-data_na_na.meta.json
# ./report/audio_files_v5/shwethabr-e3fdea9f/webapp-asquire-mox-na_shwethabr-e3fdea9f_meta-data_na_na.json
# ./report/audio_files_v5/shwethabr-e3fdea9f/webapp-asquire-mox-na_shwethabr-e3fdea9f_meta-data_na_na.meta.json
# ./report/audio_files_v5/tabiya-b0a420c7/webapp-asquire-mox-na_tabiya-b0a420c7_meta-data_na_na.json
# ./report/audio_files_v5/tabiya-b0a420c7/webapp-asquire-mox-na_tabiya-b0a420c7_meta-data_na_na.meta.json
# ./report/audio_files_v5/kashyap-40765eeb/webapp-asquire-mox-na_kashyap-40765eeb_meta-data_na_na.json
# ./report/audio_files_v5/kashyap-40765eeb/webapp-asquire-mox-na_kashyap-40765eeb_meta-data_na_na.meta.json
# ./report/audio_files_v5/misfit-1d4c38e3/webapp-asquire-mox-na_misfit-1d4c38e3_meta-data_na_na.json
# ./report/audio_files_v5/misfit-1d4c38e3/webapp-asquire-mox-na_misfit-1d4c38e3_meta-data_na_na.meta.json
# ./report/audio_files_v5/siddharths-4d513099/webapp-asquire-mox-na_siddharths-4d513099_meta-data_na_na.json
# ./report/audio_files_v5/siddharths-4d513099/webapp-asquire-mox-na_siddharths-4d513099_meta-data_na_na.meta.json
# ./report/audio_files_v5/sharthak-caa8a750/webapp-asquire-mox-na_sharthak-caa8a750_meta-data_na_na.json
# ./report/audio_files_v5/sharthak-caa8a750/webapp-asquire-mox-na_sharthak-caa8a750_meta-data_na_na.meta.json
# ./report/audio_files_v5/kushnoob-de0e9243/webapp-asquire-mox-na_kushnoob-de0e9243_meta-data_na_na.json
# ./report/audio_files_v5/kushnoob-de0e9243/webapp-asquire-mox-na_kushnoob-de0e9243_meta-data_na_na.meta.json
# ./report/audio_files_v5/mars-fb205e6b/webapp-asquire-mox-na_mars-fb205e6b_meta-data_na_na.json
# ./report/audio_files_v5/mars-fb205e6b/webapp-asquire-mox-na_mars-fb205e6b_meta-data_na_na.meta.json
# ./report/audio_files_v5/soumili-7247e29c/webapp-asquire-mox-na_soumili-7247e29c_meta-data_na_na.json
# ./report/audio_files_v5/soumili-7247e29c/webapp-asquire-mox-na_soumili-7247e29c_meta-data_na_na.meta.json
# ./report/audio_files_v5/rithika-bb369710/webapp-asquire-mox-na_rithika-bb369710_meta-data_na_na.json
# ./report/audio_files_v5/rithika-bb369710/webapp-asquire-mox-na_rithika-bb369710_meta-data_na_na.meta.json
# ./report/audio_files_v5/cooldudeo-060466fb/webapp-asquire-mox-na_cooldudeo-060466fb_meta-data_na_na.json
# ./report/audio_files_v5/cooldudeo-060466fb/webapp-asquire-mox-na_cooldudeo-060466fb_meta-data_na_na.meta.json
# ./report/audio_files_v5/siddhant-3294eacc/webapp-asquire-mox-na_siddhant-3294eacc_meta-data_na_na.json
# ./report/audio_files_v5/siddhant-3294eacc/webapp-asquire-mox-na_siddhant-3294eacc_meta-data_na_na.meta.json
# ./report/audio_files_v5/sowmya-5394e06b/webapp-asquire-mox-na_sowmya-5394e06b_meta-data_na_na.json
# ./report/audio_files_v5/sowmya-5394e06b/webapp-asquire-mox-na_sowmya-5394e06b_meta-data_na_na.meta.json
# ./report/audio_files_v5/vasavik-302c3ef2/webapp-asquire-mox-koi_vasavik-302c3ef2_meta-data_na_na.json
# ./report/audio_files_v5/vasavik-302c3ef2/webapp-asquire-mox-koi_vasavik-302c3ef2_meta-data_na_na.meta.json
# ./report/audio_files_v5/mahima-3d6c6d97/webapp-asquire-mox-na_mahima-3d6c6d97_meta-data_na_na.json
# ./report/audio_files_v5/mahima-3d6c6d97/webapp-asquire-mox-na_mahima-3d6c6d97_meta-data_na_na.meta.json
# ./report/audio_files_v5/surabhi-3bce259b/webapp-asquire-mox-na_surabhi-3bce259b_meta-data_na_na.json
# ./report/audio_files_v5/surabhi-3bce259b/webapp-asquire-mox-na_surabhi-3bce259b_meta-data_na_na.meta.json
# ./report/audio_files_v5/vishnuchouhan-29493c76/webapp-asquire-mox-na_vishnuchouhan-29493c76_meta-data_na_na.json
# ./report/audio_files_v5/vishnuchouhan-29493c76/webapp-asquire-mox-na_vishnuchouhan-29493c76_meta-data_na_na.meta.json
# ./report/audio_files_v5/siddharth-3005042d/webapp-asquire-mox-na_siddharth-3005042d_meta-data_na_na.json
# ./report/audio_files_v5/siddharth-3005042d/webapp-asquire-mox-na_siddharth-3005042d_meta-data_na_na.meta.json
# ./report/audio_files_v5/sahil-ccb6707f/webapp-asquire-mox-na_sahil-ccb6707f_meta-data_na_na.json
# ./report/audio_files_v5/sahil-ccb6707f/webapp-asquire-mox-na_sahil-ccb6707f_meta-data_na_na.meta.json
# ./report/audio_files_v5/ishaankumar-07727139/webapp-asquire-mox-na_ishaankumar-07727139_meta-data_na_na.json
# ./report/audio_files_v5/ishaankumar-07727139/webapp-asquire-mox-na_ishaankumar-07727139_meta-data_na_na.meta.json
# ./report/audio_files_v5/priyanshu-aa13e502/webapp-asquire-mox-koi_priyanshu-aa13e502_meta-data_na_na.json
# ./report/audio_files_v5/priyanshu-aa13e502/webapp-asquire-mox-koi_priyanshu-aa13e502_meta-data_na_na.meta.json
# ./report/audio_files_v5/selenator-2f05f52b/webapp-asquire-mox-koi_selenator-2f05f52b_meta-data_na_na.json
# ./report/audio_files_v5/selenator-2f05f52b/webapp-asquire-mox-koi_selenator-2f05f52b_meta-data_na_na.meta.json
# ./report/audio_files_v5/saurabh-2c177680/webapp-asquire-mox-na_saurabh-2c177680_meta-data_na_na.json
# ./report/audio_files_v5/saurabh-2c177680/webapp-asquire-mox-na_saurabh-2c177680_meta-data_na_na.meta.json
# ./report/audio_files_v5/sampreeth-7450afca/webapp-asquire-mox-na_sampreeth-7450afca_meta-data_na_na.json
# ./report/audio_files_v5/sampreeth-7450afca/webapp-asquire-mox-na_sampreeth-7450afca_meta-data_na_na.meta.json
# ./report/audio_files_v5/mysha-898c699f/webapp-asquire-mox-na_mysha-898c699f_meta-data_na_na.json
# ./report/audio_files_v5/mysha-898c699f/webapp-asquire-mox-na_mysha-898c699f_meta-data_na_na.meta.json
# ./report/audio_files_v5/sdatta-7bdcfd3e/webapp-asquire-mox-na_sdatta-7bdcfd3e_meta-data_na_na.json
# ./report/audio_files_v5/sdatta-7bdcfd3e/webapp-asquire-mox-na_sdatta-7bdcfd3e_meta-data_na_na.meta.json
# ./report/audio_files_v5/pavan-39ee4a48/webapp-asquire-mox-na_pavan-39ee4a48_meta-data_na_na.json
# ./report/audio_files_v5/pavan-39ee4a48/webapp-asquire-mox-na_pavan-39ee4a48_meta-data_na_na.meta.json
# ./report/audio_files_v5/khushihalari-d00cfddc/webapp-asquire-mox-koi_khushihalari-d00cfddc_meta-data_na_na.json
# ./report/audio_files_v5/khushihalari-d00cfddc/webapp-asquire-mox-koi_khushihalari-d00cfddc_meta-data_na_na.meta.json
# ./report/audio_files_v5/divs-9d7e7115/webapp-asquire-mox-na_divs-9d7e7115_meta-data_na_na.json
# ./report/audio_files_v5/divs-9d7e7115/webapp-asquire-mox-na_divs-9d7e7115_meta-data_na_na.meta.json
# ./report/audio_files_v5/nikhil-3ab634f7/webapp-asquire-mox-na_nikhil-3ab634f7_meta-data_na_na.json
# ./report/audio_files_v5/nikhil-3ab634f7/webapp-asquire-mox-na_nikhil-3ab634f7_meta-data_na_na.meta.json
# ./report/audio_files_v5/isha-fb54aa3a/webapp-asquire-mox-na_isha-fb54aa3a_meta-data_na_na.json
# ./report/audio_files_v5/isha-fb54aa3a/webapp-asquire-mox-na_isha-fb54aa3a_meta-data_na_na.meta.json
# ./report/audio_files_v5/shantaroy-bab0d1d0/webapp-asquire-mox-na_shantaroy-bab0d1d0_meta-data_na_na.json
# ./report/audio_files_v5/shantaroy-bab0d1d0/webapp-asquire-mox-na_shantaroy-bab0d1d0_meta-data_na_na.meta.json
# ./report/audio_files_v5/radheshyam-7d73c356/webapp-asquire-mox-na_radheshyam-7d73c356_meta-data_na_na.json
# ./report/audio_files_v5/radheshyam-7d73c356/webapp-asquire-mox-na_radheshyam-7d73c356_meta-data_na_na.meta.json
# ./report/audio_files_v5/sourabhtharwani-1b11d00b/webapp-asquire-mox-na_sourabhtharwani-1b11d00b_meta-data_na_na.json
# ./report/audio_files_v5/sourabhtharwani-1b11d00b/webapp-asquire-mox-na_sourabhtharwani-1b11d00b_meta-data_na_na.meta.json
# ./report/audio_files_v5/swarnim-14c5a3c9/webapp-asquire-mox-na_swarnim-14c5a3c9_meta-data_na_na.json
# ./report/audio_files_v5/swarnim-14c5a3c9/webapp-asquire-mox-na_swarnim-14c5a3c9_meta-data_na_na.meta.json
# ./report/audio_files_v5/shaique-bcd5c48f/webapp-asquire-mox-na_shaique-bcd5c48f_meta-data_na_na.json
# ./report/audio_files_v5/shaique-bcd5c48f/webapp-asquire-mox-na_shaique-bcd5c48f_meta-data_na_na.meta.json
# ./report/audio_files_v5/nikki-ecd92c47/webapp-asquire-mox-na_nikki-ecd92c47_meta-data_na_na.json
# ./report/audio_files_v5/nikki-ecd92c47/webapp-asquire-mox-na_nikki-ecd92c47_meta-data_na_na.meta.json
# ./report/audio_files_v5/sohampit-aa1fb04e/webapp-asquire-mox-na_sohampit-aa1fb04e_meta-data_na_na.json
# ./report/audio_files_v5/sohampit-aa1fb04e/webapp-asquire-mox-na_sohampit-aa1fb04e_meta-data_na_na.meta.json
# ./report/audio_files_v5/arhaam-350fc3e6/webapp-asquire-mox-na_arhaam-350fc3e6_meta-data_na_na.json
# ./report/audio_files_v5/arhaam-350fc3e6/webapp-asquire-mox-na_arhaam-350fc3e6_meta-data_na_na.meta.json
# ./report/audio_files_v5/aido-6028a8cf/webapp-asquire-mox-na_aido-6028a8cf_meta-data_na_na.json
# ./report/audio_files_v5/aido-6028a8cf/webapp-asquire-mox-na_aido-6028a8cf_meta-data_na_na.meta.json
# ./report/audio_files_v5/rohitrp-0c0e06b7/webapp-asquire-mox-koi_rohitrp-0c0e06b7_meta-data_na_na.json
# ./report/audio_files_v5/rohitrp-0c0e06b7/webapp-asquire-mox-koi_rohitrp-0c0e06b7_meta-data_na_na.meta.json
# ./report/audio_files_v5/sheen-3d38047e/webapp-asquire-mox-na_sheen-3d38047e_meta-data_na_na.json
# ./report/audio_files_v5/sheen-3d38047e/webapp-asquire-mox-na_sheen-3d38047e_meta-data_na_na.meta.json
# ./report/audio_files_v5/apoorva-fd85446c/webapp-asquire-mox-na_apoorva-fd85446c_meta-data_na_na.json
# ./report/audio_files_v5/apoorva-fd85446c/webapp-asquire-mox-na_apoorva-fd85446c_meta-data_na_na.meta.json
# ./report/audio_files_v5/sayanoisy-51f8728f/webapp-asquire-mox-na_sayanoisy-51f8728f_meta-data_na_na.json
# ./report/audio_files_v5/sayanoisy-51f8728f/webapp-asquire-mox-na_sayanoisy-51f8728f_meta-data_na_na.meta.json
# ./report/audio_files_v5/mohitchouhan-b53e2a72/webapp-asquire-mox-na_mohitchouhan-b53e2a72_meta-data_na_na.json
# ./report/audio_files_v5/mohitchouhan-b53e2a72/webapp-asquire-mox-na_mohitchouhan-b53e2a72_meta-data_na_na.meta.json
# ./report/audio_files_v5/dashrath-214fb603/webapp-asquire-mox-na_dashrath-214fb603_meta-data_na_na.json
# ./report/audio_files_v5/dashrath-214fb603/webapp-asquire-mox-na_dashrath-214fb603_meta-data_na_na.meta.json
# ./report/audio_files_v5/baskarchouhan-a4f102a7/webapp-asquire-mox-na_baskarchouhan-a4f102a7_meta-data_na_na.json
# ./report/audio_files_v5/baskarchouhan-a4f102a7/webapp-asquire-mox-na_baskarchouhan-a4f102a7_meta-data_na_na.meta.json
# ./report/audio_files_v5/shreeram-61f265ce/webapp-asquire-mox-na_shreeram-61f265ce_meta-data_na_na.json
# ./report/audio_files_v5/shreeram-61f265ce/webapp-asquire-mox-na_shreeram-61f265ce_meta-data_na_na.meta.json
# ./report/audio_files_v5/cpujara-65f03922/webapp-asquire-mox-na_cpujara-65f03922_meta-data_na_na.json
# ./report/audio_files_v5/cpujara-65f03922/webapp-asquire-mox-na_cpujara-65f03922_meta-data_na_na.meta.json
# ./report/audio_files_v5/pankajpa-3e25d762/webapp-asquire-mox-na_pankajpa-3e25d762_meta-data_na_na.json
# ./report/audio_files_v5/pankajpa-3e25d762/webapp-asquire-mox-na_pankajpa-3e25d762_meta-data_na_na.meta.json
# ./report/audio_files_v5/anqa-18ddc889/webapp-asquire-mox-na_anqa-18ddc889_meta-data_na_na.json
# ./report/audio_files_v5/anqa-18ddc889/webapp-asquire-mox-na_anqa-18ddc889_meta-data_na_na.meta.json
# ./report/audio_files_v5/ashishkakne-e2b13592/webapp-asquire-mox-na_ashishkakne-e2b13592_meta-data_na_na.json
# ./report/audio_files_v5/ashishkakne-e2b13592/webapp-asquire-mox-na_ashishkakne-e2b13592_meta-data_na_na.meta.json
# ./report/audio_files_v5/madhusudhan-e57163ce/webapp-asquire-mox-na_madhusudhan-e57163ce_meta-data_na_na.json
# ./report/audio_files_v5/madhusudhan-e57163ce/webapp-asquire-mox-na_madhusudhan-e57163ce_meta-data_na_na.meta.json
# ./report/audio_files_v5/quirky-eaafd9e5/webapp-asquire-mox-na_quirky-eaafd9e5_meta-data_na_na.json
# ./report/audio_files_v5/quirky-eaafd9e5/webapp-asquire-mox-na_quirky-eaafd9e5_meta-data_na_na.meta.json
# ./report/audio_files_v5/priyanka-e33c5cf7/webapp-asquire-mox-na_priyanka-e33c5cf7_meta-data_na_na.json
# ./report/audio_files_v5/priyanka-e33c5cf7/webapp-asquire-mox-na_priyanka-e33c5cf7_meta-data_na_na.meta.json
# ./report/audio_files_v5/shivanshu-41a93b49/webapp-asquire-mox-na_shivanshu-41a93b49_meta-data_na_na.json
# ./report/audio_files_v5/shivanshu-41a93b49/webapp-asquire-mox-na_shivanshu-41a93b49_meta-data_na_na.meta.json
# ./report/audio_files_v5/sumit-19f76935/webapp-asquire-mox-na_sumit-19f76935_meta-data_na_na.json
# ./report/audio_files_v5/sumit-19f76935/webapp-asquire-mox-na_sumit-19f76935_meta-data_na_na.meta.json
# ./report/audio_files_v5/bibha-e172b7f3/webapp-asquire-mox-na_bibha-e172b7f3_meta-data_na_na.json
# ./report/audio_files_v5/bibha-e172b7f3/webapp-asquire-mox-na_bibha-e172b7f3_meta-data_na_na.meta.json
# ./report/audio_files_v5/varshitha-f72f8ed4/webapp-asquire-mox-na_varshitha-f72f8ed4_meta-data_na_na.json
# ./report/audio_files_v5/varshitha-f72f8ed4/webapp-asquire-mox-na_varshitha-f72f8ed4_meta-data_na_na.meta.json
# ./report/audio_files_v5/shashi-c18c8f75/webapp-asquire-mox-na_shashi-c18c8f75_meta-data_na_na.json
# ./report/audio_files_v5/shashi-c18c8f75/webapp-asquire-mox-na_shashi-c18c8f75_meta-data_na_na.meta.json
# ./report/audio_files_v5/mharon-27d322d2/webapp-asquire-mox-na_mharon-27d322d2_meta-data_na_na.json
# ./report/audio_files_v5/mharon-27d322d2/webapp-asquire-mox-na_mharon-27d322d2_meta-data_na_na.meta.json
# ./report/audio_files_v5/karthiksvasisht-e7d9c436/webapp-asquire-mox-na_karthiksvasisht-e7d9c436_meta-data_na_na.json
# ./report/audio_files_v5/karthiksvasisht-e7d9c436/webapp-asquire-mox-na_karthiksvasisht-e7d9c436_meta-data_na_na.meta.json
# ./report/audio_files_v5/aryan-7638ca98/webapp-asquire-mox-na_aryan-7638ca98_meta-data_na_na.json
# ./report/audio_files_v5/aryan-7638ca98/webapp-asquire-mox-na_aryan-7638ca98_meta-data_na_na.meta.json
# ./report/audio_files_v5/tony-3dc3d463/webapp-asquire-mox-na_tony-3dc3d463_meta-data_na_na.json
# ./report/audio_files_v5/tony-3dc3d463/webapp-asquire-mox-na_tony-3dc3d463_meta-data_na_na.meta.json
# ./report/audio_files_v5/wajiha-0a4be51c/webapp-asquire-mox-na_wajiha-0a4be51c_meta-data_na_na.json
# ./report/audio_files_v5/wajiha-0a4be51c/webapp-asquire-mox-na_wajiha-0a4be51c_meta-data_na_na.meta.json
# ./report/audio_files_v5/crazymahesh-556a594c/webapp-asquire-mox-na_crazymahesh-556a594c_meta-data_na_na.json
# ./report/audio_files_v5/crazymahesh-556a594c/webapp-asquire-mox-na_crazymahesh-556a594c_meta-data_na_na.meta.json
# ./report/audio_files_v5/bazila-cfad5826/webapp-asquire-mox-na_bazila-cfad5826_meta-data_na_na.json
# ./report/audio_files_v5/bazila-cfad5826/webapp-asquire-mox-na_bazila-cfad5826_meta-data_na_na.meta.json
# ./report/audio_files_v5/riya-1f47e868/webapp-asquire-mox-na_riya-1f47e868_meta-data_na_na.json
# ./report/audio_files_v5/riya-1f47e868/webapp-asquire-mox-na_riya-1f47e868_meta-data_na_na.meta.json
# ./report/audio_files_v5/bharath-0e0e348f/webapp-asquire-mox-na_bharath-0e0e348f_meta-data_na_na.json
# ./report/audio_files_v5/bharath-0e0e348f/webapp-asquire-mox-na_bharath-0e0e348f_meta-data_na_na.meta.json
# ./report/audio_files_v5/jeevan-a47b5fa1/webapp-asquire-mox-na_jeevan-a47b5fa1_meta-data_na_na.json
# ./report/audio_files_v5/jeevan-a47b5fa1/webapp-asquire-mox-na_jeevan-a47b5fa1_meta-data_na_na.meta.json
# ./report/audio_files_v5/abhishek-77927894/webapp-asquire-mox-na_abhishek-77927894_meta-data_na_na.json
# ./report/audio_files_v5/abhishek-77927894/webapp-asquire-mox-na_abhishek-77927894_meta-data_na_na.meta.json
# ./report/audio_files_v5/arsalaanreyaz-27160c04/webapp-asquire-mox-na_arsalaanreyaz-27160c04_meta-data_na_na.json
# ./report/audio_files_v5/arsalaanreyaz-27160c04/webapp-asquire-mox-na_arsalaanreyaz-27160c04_meta-data_na_na.meta.json
# ./report/audio_files_v5/amitbiswas-90a28883/webapp-asquire-mox-na_amitbiswas-90a28883_meta-data_na_na.json
# ./report/audio_files_v5/amitbiswas-90a28883/webapp-asquire-mox-na_amitbiswas-90a28883_meta-data_na_na.meta.json
# ./report/audio_files_v5/kqari-52b0cddc/webapp-asquire-mox-na_kqari-52b0cddc_meta-data_na_na.json
# ./report/audio_files_v5/kqari-52b0cddc/webapp-asquire-mox-na_kqari-52b0cddc_meta-data_na_na.meta.json
# ./report/audio_files_v5/roopantj-c5e4e909/webapp-asquire-mox-na_roopantj-c5e4e909_meta-data_na_na.json
# ./report/audio_files_v5/roopantj-c5e4e909/webapp-asquire-mox-na_roopantj-c5e4e909_meta-data_na_na.meta.json
# ./report/audio_files_v5/jibran-f4cf65d8/webapp-asquire-mox-na_jibran-f4cf65d8_meta-data_na_na.json
# ./report/audio_files_v5/jibran-f4cf65d8/webapp-asquire-mox-na_jibran-f4cf65d8_meta-data_na_na.meta.json
# ./report/audio_files_v5/hmrishav-6b62eb0c/webapp-asquire-mox-na_hmrishav-6b62eb0c_meta-data_na_na.json
# ./report/audio_files_v5/hmrishav-6b62eb0c/webapp-asquire-mox-na_hmrishav-6b62eb0c_meta-data_na_na.meta.json
# ./report/audio_files_v5/minakshi-43aefdc5/webapp-asquire-mox-na_minakshi-43aefdc5_meta-data_na_na.json
# ./report/audio_files_v5/minakshi-43aefdc5/webapp-asquire-mox-na_minakshi-43aefdc5_meta-data_na_na.meta.json
# ./report/audio_files_v5/asim-d0ebd588/webapp-asquire-mox-na_asim-d0ebd588_meta-data_na_na.json
# ./report/audio_files_v5/asim-d0ebd588/webapp-asquire-mox-na_asim-d0ebd588_meta-data_na_na.meta.json
# ./report/audio_files_v5/pavan-30ce39e3/webapp-asquire-mox-na_pavan-30ce39e3_meta-data_na_na.json
# ./report/audio_files_v5/pavan-30ce39e3/webapp-asquire-mox-na_pavan-30ce39e3_meta-data_na_na.meta.json
# ./report/audio_files_v5/venkatesh-987f47bb/webapp-asquire-mox-na_venkatesh-987f47bb_meta-data_na_na.json
# ./report/audio_files_v5/venkatesh-987f47bb/webapp-asquire-mox-na_venkatesh-987f47bb_meta-data_na_na.meta.json
# ./report/audio_files_v5/uyiut-c544cde3/webapp-asquire-mox-na_uyiut-c544cde3_meta-data_na_na.json
# ./report/audio_files_v5/uyiut-c544cde3/webapp-asquire-mox-na_uyiut-c544cde3_meta-data_na_na.meta.json
# ./report/audio_files_v5/mks-74d505b0/webapp-asquire-mox-na_mks-74d505b0_meta-data_na_na.json
# ./report/audio_files_v5/mks-74d505b0/webapp-asquire-mox-na_mks-74d505b0_meta-data_na_na.meta.json
# ./report/audio_files_v5/nikhilpatel-d5fc985e/webapp-asquire-mox-na_nikhilpatel-d5fc985e_meta-data_na_na.json
# ./report/audio_files_v5/nikhilpatel-d5fc985e/webapp-asquire-mox-na_nikhilpatel-d5fc985e_meta-data_na_na.meta.json
# ./report/audio_files_v5/seerat-bc7c0df4/webapp-asquire-mox-na_seerat-bc7c0df4_meta-data_na_na.json
# ./report/audio_files_v5/seerat-bc7c0df4/webapp-asquire-mox-na_seerat-bc7c0df4_meta-data_na_na.meta.json
# ./report/audio_files_v5/udvass-3c6f9b2c/webapp-asquire-mox-na_udvass-3c6f9b2c_meta-data_na_na.json
# ./report/audio_files_v5/udvass-3c6f9b2c/webapp-asquire-mox-na_udvass-3c6f9b2c_meta-data_na_na.meta.json
# ./report/audio_files_v5/shivendra-506ba7ab/webapp-asquire-mox-na_shivendra-506ba7ab_meta-data_na_na.json
# ./report/audio_files_v5/shivendra-506ba7ab/webapp-asquire-mox-na_shivendra-506ba7ab_meta-data_na_na.meta.json
# ./report/audio_files_v5/tanushree-de60d99d/webapp-asquire-mox-na_tanushree-de60d99d_meta-data_na_na.json
# ./report/audio_files_v5/tanushree-de60d99d/webapp-asquire-mox-na_tanushree-de60d99d_meta-data_na_na.meta.json
# ./report/audio_files_v5/jiten-019d0465/webapp-asquire-mox-na_jiten-019d0465_meta-data_na_na.json
# ./report/audio_files_v5/jiten-019d0465/webapp-asquire-mox-na_jiten-019d0465_meta-data_na_na.meta.json
# ./report/audio_files_v5/anish-3c849474/webapp-asquire-mox-na_anish-3c849474_meta-data_na_na.json
# ./report/audio_files_v5/anish-3c849474/webapp-asquire-mox-na_anish-3c849474_meta-data_na_na.meta.json
# ./report/audio_files_v5/shasm-8d168cc1/webapp-asquire-mox-na_shasm-8d168cc1_meta-data_na_na.json
# ./report/audio_files_v5/shasm-8d168cc1/webapp-asquire-mox-na_shasm-8d168cc1_meta-data_na_na.meta.json
# ./report/audio_files_v5/arun-f4dfcb91/webapp-asquire-mox-na_arun-f4dfcb91_meta-data_na_na.json
# ./report/audio_files_v5/arun-f4dfcb91/webapp-asquire-mox-na_arun-f4dfcb91_meta-data_na_na.meta.json
# ./report/audio_files_v5/gyamaryana-e2c7bce8/webapp-asquire-mox-na_gyamaryana-e2c7bce8_meta-data_na_na.json
# ./report/audio_files_v5/gyamaryana-e2c7bce8/webapp-asquire-mox-na_gyamaryana-e2c7bce8_meta-data_na_na.meta.json
# ./report/audio_files_v5/aditisatvika-dd09b820/webapp-asquire-mox-na_aditisatvika-dd09b820_meta-data_na_na.json
# ./report/audio_files_v5/aditisatvika-dd09b820/webapp-asquire-mox-na_aditisatvika-dd09b820_meta-data_na_na.meta.json
# ./report/audio_files_v5/kuna-dd41d753/webapp-asquire-mox-na_kuna-dd41d753_meta-data_na_na.json
# ./report/audio_files_v5/kuna-dd41d753/webapp-asquire-mox-na_kuna-dd41d753_meta-data_na_na.meta.json
# ./report/audio_files_v5/harisk-6f82d610/webapp-asquire-mox-na_harisk-6f82d610_meta-data_na_na.json
# ./report/audio_files_v5/harisk-6f82d610/webapp-asquire-mox-na_harisk-6f82d610_meta-data_na_na.meta.json
# ./report/audio_files_v5/sneha-f1987b07/webapp-asquire-mox-na_sneha-f1987b07_meta-data_na_na.json
# ./report/audio_files_v5/sneha-f1987b07/webapp-asquire-mox-na_sneha-f1987b07_meta-data_na_na.meta.json
# ./report/audio_files_v5/shashank-92792634/webapp-asquire-mox-na_shashank-92792634_meta-data_na_na.json
# ./report/audio_files_v5/shashank-92792634/webapp-asquire-mox-na_shashank-92792634_meta-data_na_na.meta.json
# ./report/audio_files_v5/saiforindia-a3e9036e/webapp-asquire-mox-na_saiforindia-a3e9036e_meta-data_na_na.json
# ./report/audio_files_v5/saiforindia-a3e9036e/webapp-asquire-mox-na_saiforindia-a3e9036e_meta-data_na_na.meta.json
# ./report/audio_files_v5/navneeth-498e541d/webapp-asquire-mox-na_navneeth-498e541d_meta-data_na_na.json
# ./report/audio_files_v5/navneeth-498e541d/webapp-asquire-mox-na_navneeth-498e541d_meta-data_na_na.meta.json
# ./report/audio_files_v5/pragnaniranjan-8fa5dd73/webapp-asquire-mox-na_pragnaniranjan-8fa5dd73_meta-data_na_na.json
# ./report/audio_files_v5/pragnaniranjan-8fa5dd73/webapp-asquire-mox-na_pragnaniranjan-8fa5dd73_meta-data_na_na.meta.json
# ./report/audio_files_v5/koshanqari-56cf98b3/webapp-asquire-mox-na_koshanqari-56cf98b3_meta-data_na_na.json
# ./report/audio_files_v5/koshanqari-56cf98b3/webapp-asquire-mox-na_koshanqari-56cf98b3_meta-data_na_na.meta.json
# ./report/audio_files_v5/naveen-9d578be4/webapp-asquire-mox-koi_naveen-9d578be4_meta-data_na_na.json
# ./report/audio_files_v5/naveen-9d578be4/webapp-asquire-mox-koi_naveen-9d578be4_meta-data_na_na.meta.json
# ./report/audio_files_v5/chitransh-031e3c16/webapp-asquire-mox-na_chitransh-031e3c16_meta-data_na_na.json
# ./report/audio_files_v5/chitransh-031e3c16/webapp-asquire-mox-na_chitransh-031e3c16_meta-data_na_na.meta.json
# ./report/audio_files_v5/quizee-208bbae9/webapp-asquire-mox-na_quizee-208bbae9_meta-data_na_na.json
# ./report/audio_files_v5/quizee-208bbae9/webapp-asquire-mox-na_quizee-208bbae9_meta-data_na_na.meta.json
# ./report/audio_files_v5/poojavh-406e407d/webapp-asquire-mox-na_poojavh-406e407d_meta-data_na_na.json
# ./report/audio_files_v5/poojavh-406e407d/webapp-asquire-mox-na_poojavh-406e407d_meta-data_na_na.meta.json
# ./report/audio_files_v5/abhayjeet-43450bd5/webapp-asquire-mox-na_abhayjeet-43450bd5_meta-data_na_na.json
# ./report/audio_files_v5/abhayjeet-43450bd5/webapp-asquire-mox-na_abhayjeet-43450bd5_meta-data_na_na.meta.json
# ./report/audio_files_v5/shruti-b3f32eb9/webapp-asquire-mox-na_shruti-b3f32eb9_meta-data_na_na.json
# ./report/audio_files_v5/shruti-b3f32eb9/webapp-asquire-mox-na_shruti-b3f32eb9_meta-data_na_na.meta.json
# ./report/audio_files_v5/jagarnath-9a8550a3/webapp-asquire-mox-na_jagarnath-9a8550a3_meta-data_na_na.json
# ./report/audio_files_v5/jagarnath-9a8550a3/webapp-asquire-mox-na_jagarnath-9a8550a3_meta-data_na_na.meta.json
# ./report/audio_files_v5/namrathakhasnis-feb7afad/webapp-asquire-mox-na_namrathakhasnis-feb7afad_meta-data_na_na.json
# ./report/audio_files_v5/namrathakhasnis-feb7afad/webapp-asquire-mox-na_namrathakhasnis-feb7afad_meta-data_na_na.meta.json
# ./report/audio_files_v5/mickydeori-60b84275/webapp-asquire-mox-na_mickydeori-60b84275_meta-data_na_na.json
# ./report/audio_files_v5/mickydeori-60b84275/webapp-asquire-mox-na_mickydeori-60b84275_meta-data_na_na.meta.json
# ./report/audio_files_v5/ap-ae925d37/webapp-asquire-mox-na_ap-ae925d37_meta-data_na_na.json
# ./report/audio_files_v5/ap-ae925d37/webapp-asquire-mox-na_ap-ae925d37_meta-data_na_na.meta.json
# ./report/audio_files_v5/skywalker-3239fc01/webapp-asquire-mox-na_skywalker-3239fc01_meta-data_na_na.json
# ./report/audio_files_v5/skywalker-3239fc01/webapp-asquire-mox-na_skywalker-3239fc01_meta-data_na_na.meta.json
# ./report/audio_files_v5/shreyapawaskar-c8f37bb5/webapp-asquire-mox-koi_shreyapawaskar-c8f37bb5_meta-data_na_na.json
# ./report/audio_files_v5/shreyapawaskar-c8f37bb5/webapp-asquire-mox-koi_shreyapawaskar-c8f37bb5_meta-data_na_na.meta.json
# ./report/audio_files_v5/jungkook-f16a7122/webapp-asquire-mox-na_jungkook-f16a7122_meta-data_na_na.json
# ./report/audio_files_v5/jungkook-f16a7122/webapp-asquire-mox-na_jungkook-f16a7122_meta-data_na_na.meta.json
# ./report/audio_files_v5/ravisk-cd186836/webapp-asquire-mox-na_ravisk-cd186836_meta-data_na_na.json
# ./report/audio_files_v5/ravisk-cd186836/webapp-asquire-mox-na_ravisk-cd186836_meta-data_na_na.meta.json
# ./report/audio_files_v5/sairaj-6a8a1a21/webapp-asquire-mox-na_sairaj-6a8a1a21_meta-data_na_na.json
# ./report/audio_files_v5/sairaj-6a8a1a21/webapp-asquire-mox-na_sairaj-6a8a1a21_meta-data_na_na.meta.json
# ./report/audio_files_v5/arjundeori-b1524a19/webapp-asquire-mox-na_arjundeori-b1524a19_meta-data_na_na.json
# ./report/audio_files_v5/arjundeori-b1524a19/webapp-asquire-mox-na_arjundeori-b1524a19_meta-data_na_na.meta.json
# ./report/audio_files_v5/dkumar-2377e2ca/webapp-asquire-mox-na_dkumar-2377e2ca_meta-data_na_na.json
# ./report/audio_files_v5/dkumar-2377e2ca/webapp-asquire-mox-na_dkumar-2377e2ca_meta-data_na_na.meta.json
# ./report/audio_files_v5/amishasinha-94b8bf22/webapp-asquire-mox-na_amishasinha-94b8bf22_meta-data_na_na.json
# ./report/audio_files_v5/amishasinha-94b8bf22/webapp-asquire-mox-na_amishasinha-94b8bf22_meta-data_na_na.meta.json
# ./report/audio_files_v5/pritishmahajan-d669313f/webapp-asquire-mox-na_pritishmahajan-d669313f_meta-data_na_na.json
# ./report/audio_files_v5/pritishmahajan-d669313f/webapp-asquire-mox-na_pritishmahajan-d669313f_meta-data_na_na.meta.json
# ./report/audio_files_v5/yaturinling-c6bf69ac/webapp-asquire-mox-na_yaturinling-c6bf69ac_meta-data_na_na.json
# ./report/audio_files_v5/yaturinling-c6bf69ac/webapp-asquire-mox-na_yaturinling-c6bf69ac_meta-data_na_na.meta.json
# ./report/audio_files_v5/naved-e17e8a69/webapp-asquire-mox-na_naved-e17e8a69_meta-data_na_na.json
# ./report/audio_files_v5/naved-e17e8a69/webapp-asquire-mox-na_naved-e17e8a69_meta-data_na_na.meta.json
# ./report/audio_files_v5/prabh-a1c4387f/webapp-asquire-mox-na_prabh-a1c4387f_meta-data_na_na.json
# ./report/audio_files_v5/prabh-a1c4387f/webapp-asquire-mox-na_prabh-a1c4387f_meta-data_na_na.meta.json
# ./report/audio_files_v5/sweta-a3111c92/webapp-asquire-mox-na_sweta-a3111c92_meta-data_na_na.json
# ./report/audio_files_v5/sweta-a3111c92/webapp-asquire-mox-na_sweta-a3111c92_meta-data_na_na.meta.json
# ./report/audio_files_v5/takemi-bcc845d0/webapp-asquire-mox-na_takemi-bcc845d0_meta-data_na_na.json
# ./report/audio_files_v5/takemi-bcc845d0/webapp-asquire-mox-na_takemi-bcc845d0_meta-data_na_na.meta.json
# ./report/audio_files_v5/aayushmanraaz-a78a2d2f/webapp-asquire-mox-na_aayushmanraaz-a78a2d2f_meta-data_na_na.json
# ./report/audio_files_v5/aayushmanraaz-a78a2d2f/webapp-asquire-mox-na_aayushmanraaz-a78a2d2f_meta-data_na_na.meta.json
# ./report/audio_files_v5/neelanshu-4220f172/webapp-asquire-mox-na_neelanshu-4220f172_meta-data_na_na.json
# ./report/audio_files_v5/neelanshu-4220f172/webapp-asquire-mox-na_neelanshu-4220f172_meta-data_na_na.meta.json
# ./report/audio_files_v5/neha-d4225d24/webapp-asquire-mox-na_neha-d4225d24_meta-data_na_na.json
# ./report/audio_files_v5/neha-d4225d24/webapp-asquire-mox-na_neha-d4225d24_meta-data_na_na.meta.json
# ./report/audio_files_v5/sandeshtripathi-26b85722/webapp-asquire-mox-koi_sandeshtripathi-26b85722_meta-data_na_na.json
# ./report/audio_files_v5/sandeshtripathi-26b85722/webapp-asquire-mox-koi_sandeshtripathi-26b85722_meta-data_na_na.meta.json
# ./report/audio_files_v5/akansh-4cb9fd99/webapp-asquire-mox-na_akansh-4cb9fd99_meta-data_na_na.json
# ./report/audio_files_v5/akansh-4cb9fd99/webapp-asquire-mox-na_akansh-4cb9fd99_meta-data_na_na.meta.json
# ./report/audio_files_v5/blue-0ccd88b6/webapp-asquire-mox-na_blue-0ccd88b6_meta-data_na_na.json
# ./report/audio_files_v5/blue-0ccd88b6/webapp-asquire-mox-na_blue-0ccd88b6_meta-data_na_na.meta.json
# ./report/audio_files_v5/kunaal-5e1bdccc/webapp-asquire-mox-na_kunaal-5e1bdccc_meta-data_na_na.json
# ./report/audio_files_v5/kunaal-5e1bdccc/webapp-asquire-mox-na_kunaal-5e1bdccc_meta-data_na_na.meta.json
# ./report/audio_files_v5/deepbhalsod-0af6294f/webapp-asquire-mox-na_deepbhalsod-0af6294f_meta-data_na_na.json
# ./report/audio_files_v5/deepbhalsod-0af6294f/webapp-asquire-mox-na_deepbhalsod-0af6294f_meta-data_na_na.meta.json
# ./report/audio_files_v5/bheshaj-c0b55f3d/webapp-asquire-mox-na_bheshaj-c0b55f3d_meta-data_na_na.json
# ./report/audio_files_v5/bheshaj-c0b55f3d/webapp-asquire-mox-na_bheshaj-c0b55f3d_meta-data_na_na.meta.json
# ./report/audio_files_v5/chandrimadas-83d7ec1f/webapp-asquire-mox-na_chandrimadas-83d7ec1f_meta-data_na_na.json
# ./report/audio_files_v5/chandrimadas-83d7ec1f/webapp-asquire-mox-na_chandrimadas-83d7ec1f_meta-data_na_na.meta.json
# ./report/audio_files_v5/tufail-a5baee40/webapp-asquire-mox-na_tufail-a5baee40_meta-data_na_na.json
# ./report/audio_files_v5/tufail-a5baee40/webapp-asquire-mox-na_tufail-a5baee40_meta-data_na_na.meta.json
# ./report/audio_files_v5/nagalakshmi-98e42053/webapp-asquire-mox-na_nagalakshmi-98e42053_meta-data_na_na.json
# ./report/audio_files_v5/nagalakshmi-98e42053/webapp-asquire-mox-na_nagalakshmi-98e42053_meta-data_na_na.meta.json
# ./report/audio_files_v5/sanjanak-17449261/webapp-asquire-mox-na_sanjanak-17449261_meta-data_na_na.json
# ./report/audio_files_v5/sanjanak-17449261/webapp-asquire-mox-na_sanjanak-17449261_meta-data_na_na.meta.json
# ./report/audio_files_v5/kamranelyas-2bf3d408/webapp-asquire-mox-na_kamranelyas-2bf3d408_meta-data_na_na.json
# ./report/audio_files_v5/kamranelyas-2bf3d408/webapp-asquire-mox-na_kamranelyas-2bf3d408_meta-data_na_na.meta.json
# ./report/audio_files_v5/rupali-cc6a7114/webapp-asquire-mox-na_rupali-cc6a7114_meta-data_na_na.json
# ./report/audio_files_v5/rupali-cc6a7114/webapp-asquire-mox-na_rupali-cc6a7114_meta-data_na_na.meta.json
# ./report/audio_files_v5/rajaathiban-800a7eff/webapp-asquire-mox-koi_rajaathiban-800a7eff_meta-data_na_na.json
# ./report/audio_files_v5/rajaathiban-800a7eff/webapp-asquire-mox-koi_rajaathiban-800a7eff_meta-data_na_na.meta.json
# ./report/audio_files_v5/anubhabmajumdar-e1228853/webapp-asquire-mox-na_anubhabmajumdar-e1228853_meta-data_na_na.json
# ./report/audio_files_v5/anubhabmajumdar-e1228853/webapp-asquire-mox-na_anubhabmajumdar-e1228853_meta-data_na_na.meta.json
# ./report/audio_files_v5/soliya-c945355f/webapp-asquire-mox-na_soliya-c945355f_meta-data_na_na.json
# ./report/audio_files_v5/soliya-c945355f/webapp-asquire-mox-na_soliya-c945355f_meta-data_na_na.meta.json
# ./report/audio_files_v5/hazim-6fecfd52/webapp-asquire-mox-na_hazim-6fecfd52_meta-data_na_na.json
# ./report/audio_files_v5/hazim-6fecfd52/webapp-asquire-mox-na_hazim-6fecfd52_meta-data_na_na.meta.json
# ./report/audio_files_v5/shakir-58f7d4b2/webapp-asquire-mox-na_shakir-58f7d4b2_meta-data_na_na.json
# ./report/audio_files_v5/shakir-58f7d4b2/webapp-asquire-mox-na_shakir-58f7d4b2_meta-data_na_na.meta.json
# ./report/audio_files_v5/karans-a6a563cb/webapp-asquire-mox-na_karans-a6a563cb_meta-data_na_na.json
# ./report/audio_files_v5/karans-a6a563cb/webapp-asquire-mox-na_karans-a6a563cb_meta-data_na_na.meta.json
# ./report/audio_files_v5/rohan-271d8614/webapp-asquire-mox-na_rohan-271d8614_meta-data_na_na.json
# ./report/audio_files_v5/rohan-271d8614/webapp-asquire-mox-na_rohan-271d8614_meta-data_na_na.meta.json
# ./report/audio_files_v5/pradeep-ce05bf00/webapp-asquire-mox-na_pradeep-ce05bf00_meta-data_na_na.json
# ./report/audio_files_v5/pradeep-ce05bf00/webapp-asquire-mox-na_pradeep-ce05bf00_meta-data_na_na.meta.json
# ./report/audio_files_v5/mayanksain-561a522e/webapp-asquire-mox-na_mayanksain-561a522e_meta-data_na_na.json
# ./report/audio_files_v5/mayanksain-561a522e/webapp-asquire-mox-na_mayanksain-561a522e_meta-data_na_na.meta.json
# ./report/audio_files_v5/richo-f3ef1152/webapp-asquire-mox-na_richo-f3ef1152_meta-data_na_na.json
# ./report/audio_files_v5/richo-f3ef1152/webapp-asquire-mox-na_richo-f3ef1152_meta-data_na_na.meta.json
# ./report/audio_files_v5/niharika-a8738865/webapp-asquire-mox-na_niharika-a8738865_meta-data_na_na.json
# ./report/audio_files_v5/niharika-a8738865/webapp-asquire-mox-na_niharika-a8738865_meta-data_na_na.meta.json
# ./report/audio_files_v5/jinkarakesh-e2fe70ff/webapp-asquire-mox-koi_jinkarakesh-e2fe70ff_meta-data_na_na.json
# ./report/audio_files_v5/jinkarakesh-e2fe70ff/webapp-asquire-mox-koi_jinkarakesh-e2fe70ff_meta-data_na_na.meta.json
# ./report/audio_files_v5/thqnoo-39b65a27/webapp-asquire-mox-na_thqnoo-39b65a27_meta-data_na_na.json
# ./report/audio_files_v5/thqnoo-39b65a27/webapp-asquire-mox-na_thqnoo-39b65a27_meta-data_na_na.meta.json
# ./report/audio_files_v5/sanchari-ece57362/webapp-asquire-mox-na_sanchari-ece57362_meta-data_na_na.json
# ./report/audio_files_v5/sanchari-ece57362/webapp-asquire-mox-na_sanchari-ece57362_meta-data_na_na.meta.json
# ./report/audio_files_v5/mahi-7b9c9b51/webapp-asquire-mox-na_mahi-7b9c9b51_meta-data_na_na.json
# ./report/audio_files_v5/mahi-7b9c9b51/webapp-asquire-mox-na_mahi-7b9c9b51_meta-data_na_na.meta.json
# ./report/audio_files_v5/kira-fc779f36/webapp-asquire-mox-na_kira-fc779f36_meta-data_na_na.json
# ./report/audio_files_v5/kira-fc779f36/webapp-asquire-mox-na_kira-fc779f36_meta-data_na_na.meta.json
# ./report/audio_files_v5/saniya-c3426e28/webapp-asquire-mox-na_saniya-c3426e28_meta-data_na_na.json
# ./report/audio_files_v5/saniya-c3426e28/webapp-asquire-mox-na_saniya-c3426e28_meta-data_na_na.meta.json
# ./report/audio_files_v5/sonamgurjar-bdb0ad0d/webapp-asquire-mox-na_sonamgurjar-bdb0ad0d_meta-data_na_na.json
# ./report/audio_files_v5/sonamgurjar-bdb0ad0d/webapp-asquire-mox-na_sonamgurjar-bdb0ad0d_meta-data_na_na.meta.json
# ./report/audio_files_v5/gourav-c2e94c8d/webapp-asquire-mox-na_gourav-c2e94c8d_meta-data_na_na.json
# ./report/audio_files_v5/gourav-c2e94c8d/webapp-asquire-mox-na_gourav-c2e94c8d_meta-data_na_na.meta.json
# ./report/audio_files_v5/sanna-331c341a/webapp-asquire-mox-na_sanna-331c341a_meta-data_na_na.json
# ./report/audio_files_v5/sanna-331c341a/webapp-asquire-mox-na_sanna-331c341a_meta-data_na_na.meta.json
# ./report/audio_files_v5/ssdhillon-a25f6550/webapp-asquire-mox-na_ssdhillon-a25f6550_meta-data_na_na.json
# ./report/audio_files_v5/ssdhillon-a25f6550/webapp-asquire-mox-na_ssdhillon-a25f6550_meta-data_na_na.meta.json
# ./report/audio_files_v5/poklikayi-d8239c93/webapp-asquire-mox-na_poklikayi-d8239c93_meta-data_na_na.json
# ./report/audio_files_v5/poklikayi-d8239c93/webapp-asquire-mox-na_poklikayi-d8239c93_meta-data_na_na.meta.json
# ./report/audio_files_v5/shishupal-af147853/webapp-asquire-mox-na_shishupal-af147853_meta-data_na_na.json
# ./report/audio_files_v5/shishupal-af147853/webapp-asquire-mox-na_shishupal-af147853_meta-data_na_na.meta.json
# ./report/audio_files_v5/adarsh-d13557e5/webapp-asquire-mox-na_adarsh-d13557e5_meta-data_na_na.json
# ./report/audio_files_v5/adarsh-d13557e5/webapp-asquire-mox-na_adarsh-d13557e5_meta-data_na_na.meta.json
# ./report/audio_files_v5/azra-796ced3b/webapp-asquire-mox-na_azra-796ced3b_meta-data_na_na.json
# ./report/audio_files_v5/azra-796ced3b/webapp-asquire-mox-na_azra-796ced3b_meta-data_na_na.meta.json
# ./report/audio_files_v5/ramgopal-90c7d1d6/webapp-asquire-mox-na_ramgopal-90c7d1d6_meta-data_na_na.json
# ./report/audio_files_v5/ramgopal-90c7d1d6/webapp-asquire-mox-na_ramgopal-90c7d1d6_meta-data_na_na.meta.json
# ./report/audio_files_v5/bani-0395d07a/webapp-asquire-mox-na_bani-0395d07a_meta-data_na_na.json
# ./report/audio_files_v5/bani-0395d07a/webapp-asquire-mox-na_bani-0395d07a_meta-data_na_na.meta.json
# ./report/audio_files_v5/arundhati-c7f7cea4/webapp-asquire-mox-na_arundhati-c7f7cea4_meta-data_na_na.json
# ./report/audio_files_v5/arundhati-c7f7cea4/webapp-asquire-mox-na_arundhati-c7f7cea4_meta-data_na_na.meta.json
# ./report/audio_files_v5/anabiyah-4430ec3c/webapp-asquire-mox-na_anabiyah-4430ec3c_meta-data_na_na.json
# ./report/audio_files_v5/anabiyah-4430ec3c/webapp-asquire-mox-na_anabiyah-4430ec3c_meta-data_na_na.meta.json
# ./report/audio_files_v5/neeraj-68c24d40/webapp-asquire-mox-na_neeraj-68c24d40_meta-data_na_na.json
# ./report/audio_files_v5/neeraj-68c24d40/webapp-asquire-mox-na_neeraj-68c24d40_meta-data_na_na.meta.json
# ./report/audio_files_v5/amitraj-a4abaf74/webapp-asquire-mox-na_amitraj-a4abaf74_meta-data_na_na.json
# ./report/audio_files_v5/amitraj-a4abaf74/webapp-asquire-mox-na_amitraj-a4abaf74_meta-data_na_na.meta.json
# ./report/audio_files_v5/naseema-8464307f/webapp-asquire-mox-na_naseema-8464307f_meta-data_na_na.json
# ./report/audio_files_v5/naseema-8464307f/webapp-asquire-mox-na_naseema-8464307f_meta-data_na_na.meta.json
# ./report/audio_files_v5/kruthikasv-a2ac52c9/webapp-asquire-mox-na_kruthikasv-a2ac52c9_meta-data_na_na.json
# ./report/audio_files_v5/kruthikasv-a2ac52c9/webapp-asquire-mox-na_kruthikasv-a2ac52c9_meta-data_na_na.meta.json
# ./report/audio_files_v5/vicky-b85ee34b/webapp-asquire-mox-na_vicky-b85ee34b_meta-data_na_na.json
# ./report/audio_files_v5/vicky-b85ee34b/webapp-asquire-mox-na_vicky-b85ee34b_meta-data_na_na.meta.json
# ./report/audio_files_v5/sahil-e0bed22c/webapp-asquire-mox-na_sahil-e0bed22c_meta-data_na_na.json
# ./report/audio_files_v5/sahil-e0bed22c/webapp-asquire-mox-na_sahil-e0bed22c_meta-data_na_na.meta.json
# ./report/audio_files_v5/sudhir-51b91c93/webapp-asquire-mox-na_sudhir-51b91c93_meta-data_na_na.json
# ./report/audio_files_v5/sudhir-51b91c93/webapp-asquire-mox-na_sudhir-51b91c93_meta-data_na_na.meta.json
# ./report/audio_files_v5/zarka-5ef0e9ce/webapp-asquire-mox-na_zarka-5ef0e9ce_meta-data_na_na.json
# ./report/audio_files_v5/zarka-5ef0e9ce/webapp-asquire-mox-na_zarka-5ef0e9ce_meta-data_na_na.meta.json
# ./report/audio_files_v5/shubhangikhasnis-f43893dc/webapp-asquire-mox-na_shubhangikhasnis-f43893dc_meta-data_na_na.json
# ./report/audio_files_v5/shubhangikhasnis-f43893dc/webapp-asquire-mox-na_shubhangikhasnis-f43893dc_meta-data_na_na.meta.json
# ./report/audio_files_v5/salib-d9a5299b/webapp-asquire-mox-na_salib-d9a5299b_meta-data_na_na.json
# ./report/audio_files_v5/salib-d9a5299b/webapp-asquire-mox-na_salib-d9a5299b_meta-data_na_na.meta.json
# ./report/audio_files_v5/manjunath-1252bd9c/webapp-asquire-mox-na_manjunath-1252bd9c_meta-data_na_na.json
# ./report/audio_files_v5/manjunath-1252bd9c/webapp-asquire-mox-na_manjunath-1252bd9c_meta-data_na_na.meta.json
# ./report/audio_files_v5/rajesh-7de6bc2c/webapp-asquire-mox-na_rajesh-7de6bc2c_meta-data_na_na.json
# ./report/audio_files_v5/rajesh-7de6bc2c/webapp-asquire-mox-na_rajesh-7de6bc2c_meta-data_na_na.meta.json
# ./report/audio_files_v5/prarthana-39ab5a79/webapp-asquire-mox-na_prarthana-39ab5a79_meta-data_na_na.json
# ./report/audio_files_v5/prarthana-39ab5a79/webapp-asquire-mox-na_prarthana-39ab5a79_meta-data_na_na.meta.json
# ./report/audio_files_v5/adeel-51d76d89/webapp-asquire-mox-na_adeel-51d76d89_meta-data_na_na.json
# ./report/audio_files_v5/adeel-51d76d89/webapp-asquire-mox-na_adeel-51d76d89_meta-data_na_na.meta.json
# ./report/audio_files_v5/bhaskar-ce3fa4d7/webapp-asquire-mox-na_bhaskar-ce3fa4d7_meta-data_na_na.json
# ./report/audio_files_v5/bhaskar-ce3fa4d7/webapp-asquire-mox-na_bhaskar-ce3fa4d7_meta-data_na_na.meta.json
# ./report/audio_files_v5/jibraan-da18bcae/webapp-asquire-mox-na_jibraan-da18bcae_meta-data_na_na.json
# ./report/audio_files_v5/jibraan-da18bcae/webapp-asquire-mox-na_jibraan-da18bcae_meta-data_na_na.meta.json
# ./report/audio_files_v5/sanat-eb05ffdc/webapp-asquire-mox-na_sanat-eb05ffdc_meta-data_na_na.json
# ./report/audio_files_v5/sanat-eb05ffdc/webapp-asquire-mox-na_sanat-eb05ffdc_meta-data_na_na.meta.json
# ./report/audio_files_v5/deepa-4c842704/webapp-asquire-mox-na_deepa-4c842704_meta-data_na_na.json
# ./report/audio_files_v5/deepa-4c842704/webapp-asquire-mox-na_deepa-4c842704_meta-data_na_na.meta.json
# ./report/audio_files_v5/krishna-c75f8cf4/webapp-asquire-mox-na_krishna-c75f8cf4_meta-data_na_na.json
# ./report/audio_files_v5/krishna-c75f8cf4/webapp-asquire-mox-na_krishna-c75f8cf4_meta-data_na_na.meta.json
# ./report/audio_files_v5/nagalakshmis-34cb9d79/webapp-asquire-mox-na_nagalakshmis-34cb9d79_meta-data_na_na.json
# ./report/audio_files_v5/nagalakshmis-34cb9d79/webapp-asquire-mox-na_nagalakshmis-34cb9d79_meta-data_na_na.meta.json
# ./report/audio_files_v5/rm-02a0f969/webapp-asquire-mox-na_rm-02a0f969_meta-data_na_na.json
# ./report/audio_files_v5/rm-02a0f969/webapp-asquire-mox-na_rm-02a0f969_meta-data_na_na.meta.json
# ./report/audio_files_v5/srinivas-b89febe6/webapp-asquire-mox-na_srinivas-b89febe6_meta-data_na_na.json
# ./report/audio_files_v5/srinivas-b89febe6/webapp-asquire-mox-na_srinivas-b89febe6_meta-data_na_na.meta.json
# ./report/audio_files_v5/shivendra-49fd0914/webapp-asquire-mox-na_shivendra-49fd0914_meta-data_na_na.json
# ./report/audio_files_v5/shivendra-49fd0914/webapp-asquire-mox-na_shivendra-49fd0914_meta-data_na_na.meta.json
# ./report/audio_files_v5/anish-02df6c90/webapp-asquire-mox-na_anish-02df6c90_meta-data_na_na.json
# ./report/audio_files_v5/anish-02df6c90/webapp-asquire-mox-na_anish-02df6c90_meta-data_na_na.meta.json
# ./report/audio_files_v5/ananyach-9a6a2c78/webapp-asquire-mox-na_ananyach-9a6a2c78_meta-data_na_na.json
# ./report/audio_files_v5/ananyach-9a6a2c78/webapp-asquire-mox-na_ananyach-9a6a2c78_meta-data_na_na.meta.json
# ./report/audio_files_v5/muqaddas-50022e79/webapp-asquire-mox-na_muqaddas-50022e79_meta-data_na_na.json
# ./report/audio_files_v5/muqaddas-50022e79/webapp-asquire-mox-na_muqaddas-50022e79_meta-data_na_na.meta.json
# ./report/audio_files_v5/vinay-56bb71de/webapp-asquire-mox-na_vinay-56bb71de_meta-data_na_na.json
# ./report/audio_files_v5/vinay-56bb71de/webapp-asquire-mox-na_vinay-56bb71de_meta-data_na_na.meta.json
# ./report/audio_files_v5/ramswaroop-8fd26b2a/webapp-asquire-mox-na_ramswaroop-8fd26b2a_meta-data_na_na.json
# ./report/audio_files_v5/ramswaroop-8fd26b2a/webapp-asquire-mox-na_ramswaroop-8fd26b2a_meta-data_na_na.meta.json
# ./report/audio_files_v5/nikhil-0e7b9f80/webapp-asquire-mox-na_nikhil-0e7b9f80_meta-data_na_na.json
# ./report/audio_files_v5/nikhil-0e7b9f80/webapp-asquire-mox-na_nikhil-0e7b9f80_meta-data_na_na.meta.json
# ./report/audio_files_v5/jayasurya-99f989e3/webapp-asquire-mox-na_jayasurya-99f989e3_meta-data_na_na.json
# ./report/audio_files_v5/jayasurya-99f989e3/webapp-asquire-mox-na_jayasurya-99f989e3_meta-data_na_na.meta.json
# ./report/audio_files_v5/bhargavee-70c0073e/webapp-asquire-mox-na_bhargavee-70c0073e_meta-data_na_na.json
# ./report/audio_files_v5/bhargavee-70c0073e/webapp-asquire-mox-na_bhargavee-70c0073e_meta-data_na_na.meta.json
# ./report/audio_files_v5/rukhsana-d7170e62/webapp-asquire-mox-na_rukhsana-d7170e62_meta-data_na_na.json
# ./report/audio_files_v5/rukhsana-d7170e62/webapp-asquire-mox-na_rukhsana-d7170e62_meta-data_na_na.meta.json
# ./report/audio_files_v5/pabin-288d0c22/webapp-asquire-mox-na_pabin-288d0c22_meta-data_na_na.json
# ./report/audio_files_v5/pabin-288d0c22/webapp-asquire-mox-na_pabin-288d0c22_meta-data_na_na.meta.json
# ./report/audio_files_v5/shwethabr-e3fdea9f/webapp-asquire-mox-na_shwethabr-e3fdea9f_meta-data_na_na.json
# ./report/audio_files_v5/shwethabr-e3fdea9f/webapp-asquire-mox-na_shwethabr-e3fdea9f_meta-data_na_na.meta.json
# ./report/audio_files_v5/tabiya-b0a420c7/webapp-asquire-mox-na_tabiya-b0a420c7_meta-data_na_na.json
# ./report/audio_files_v5/tabiya-b0a420c7/webapp-asquire-mox-na_tabiya-b0a420c7_meta-data_na_na.meta.json
# ./report/audio_files_v5/kashyap-40765eeb/webapp-asquire-mox-na_kashyap-40765eeb_meta-data_na_na.json
# ./report/audio_files_v5/kashyap-40765eeb/webapp-asquire-mox-na_kashyap-40765eeb_meta-data_na_na.meta.json
# ./report/audio_files_v5/misfit-1d4c38e3/webapp-asquire-mox-na_misfit-1d4c38e3_meta-data_na_na.json
# ./report/audio_files_v5/misfit-1d4c38e3/webapp-asquire-mox-na_misfit-1d4c38e3_meta-data_na_na.meta.json
# ./report/audio_files_v5/siddharths-4d513099/webapp-asquire-mox-na_siddharths-4d513099_meta-data_na_na.json
# ./report/audio_files_v5/siddharths-4d513099/webapp-asquire-mox-na_siddharths-4d513099_meta-data_na_na.meta.json
# ./report/audio_files_v5/sharthak-caa8a750/webapp-asquire-mox-na_sharthak-caa8a750_meta-data_na_na.json
# ./report/audio_files_v5/sharthak-caa8a750/webapp-asquire-mox-na_sharthak-caa8a750_meta-data_na_na.meta.json
# ./report/audio_files_v5/kushnoob-de0e9243/webapp-asquire-mox-na_kushnoob-de0e9243_meta-data_na_na.json
# ./report/audio_files_v5/kushnoob-de0e9243/webapp-asquire-mox-na_kushnoob-de0e9243_meta-data_na_na.meta.json
# ./report/audio_files_v5/mars-fb205e6b/webapp-asquire-mox-na_mars-fb205e6b_meta-data_na_na.json
# ./report/audio_files_v5/mars-fb205e6b/webapp-asquire-mox-na_mars-fb205e6b_meta-data_na_na.meta.json
# ./report/audio_files_v5/soumili-7247e29c/webapp-asquire-mox-na_soumili-7247e29c_meta-data_na_na.json
# ./report/audio_files_v5/soumili-7247e29c/webapp-asquire-mox-na_soumili-7247e29c_meta-data_na_na.meta.json
# ./report/audio_files_v5/rithika-bb369710/webapp-asquire-mox-na_rithika-bb369710_meta-data_na_na.json
# ./report/audio_files_v5/rithika-bb369710/webapp-asquire-mox-na_rithika-bb369710_meta-data_na_na.meta.json
# ./report/audio_files_v5/cooldudeo-060466fb/webapp-asquire-mox-na_cooldudeo-060466fb_meta-data_na_na.json
# ./report/audio_files_v5/cooldudeo-060466fb/webapp-asquire-mox-na_cooldudeo-060466fb_meta-data_na_na.meta.json
# ./report/audio_files_v5/siddhant-3294eacc/webapp-asquire-mox-na_siddhant-3294eacc_meta-data_na_na.json
# ./report/audio_files_v5/siddhant-3294eacc/webapp-asquire-mox-na_siddhant-3294eacc_meta-data_na_na.meta.json
# ./report/audio_files_v5/sowmya-5394e06b/webapp-asquire-mox-na_sowmya-5394e06b_meta-data_na_na.json
# ./report/audio_files_v5/sowmya-5394e06b/webapp-asquire-mox-na_sowmya-5394e06b_meta-data_na_na.meta.json
# ./report/audio_files_v5/vasavik-302c3ef2/webapp-asquire-mox-koi_vasavik-302c3ef2_meta-data_na_na.json
# ./report/audio_files_v5/vasavik-302c3ef2/webapp-asquire-mox-koi_vasavik-302c3ef2_meta-data_na_na.meta.json
# ./report/audio_files_v5/mahima-3d6c6d97/webapp-asquire-mox-na_mahima-3d6c6d97_meta-data_na_na.json
# ./report/audio_files_v5/mahima-3d6c6d97/webapp-asquire-mox-na_mahima-3d6c6d97_meta-data_na_na.meta.json
# ./report/audio_files_v5/surabhi-3bce259b/webapp-asquire-mox-na_surabhi-3bce259b_meta-data_na_na.json
# ./report/audio_files_v5/surabhi-3bce259b/webapp-asquire-mox-na_surabhi-3bce259b_meta-data_na_na.meta.json
# ...
# ./report/audio_files_v5/rajaathiban-800a7eff/webapp-asquire-mox-koi_rajaathiban-800a7eff_meta-data_na_na.meta.json
# ./report/audio_files_v5/anubhabmajumdar-e1228853/webapp-asquire-mox-na_anubhabmajumdar-e1228853_meta-data_na_na.json
# ./report/audio_files_v5/anubhabmajumdar-e1228853/webapp-asquire-mox-na_anubhabmajumdar-e1228853_meta-data_na_na.meta.json
# ./report/audio_files_v5/soliya-c945355f/webapp-asquire-mox-na_soliya-c945355f_meta-data_na_na.json
# ./report/audio_files_v5/soliya-c945355f/webapp-asquire-mox-na_soliya-c945355f_meta-data_na_na.meta.json
# ./report/audio_files_v5/hazim-6fecfd52/webapp-asquire-mox-na_hazim-6fecfd52_meta-data_na_na.json
# ./report/audio_files_v5/hazim-6fecfd52/webapp-asquire-mox-na_hazim-6fecfd52_meta-data_na_na.meta.json
# ./report/audio_files_v5/shakir-58f7d4b2/webapp-asquire-mox-na_shakir-58f7d4b2_meta-data_na_na.json
# ./report/audio_files_v5/shakir-58f7d4b2/webapp-asquire-mox-na_shakir-58f7d4b2_meta-data_na_na.meta.json
# ./report/audio_files_v5/karans-a6a563cb/webapp-asquire-mox-na_karans-a6a563cb_meta-data_na_na.json
# ./report/audio_files_v5/karans-a6a563cb/webapp-asquire-mox-na_karans-a6a563cb_meta-data_na_na.meta.json
# ./report/audio_files_v5/rohan-271d8614/webapp-asquire-mox-na_rohan-271d8614_meta-data_na_na.json
# ./report/audio_files_v5/rohan-271d8614/webapp-asquire-mox-na_rohan-271d8614_meta-data_na_na.meta.json
# ./report/audio_files_v5/pradeep-ce05bf00/webapp-asquire-mox-na_pradeep-ce05bf00_meta-data_na_na.json
# ./report/audio_files_v5/pradeep-ce05bf00/webapp-asquire-mox-na_pradeep-ce05bf00_meta-data_na_na.meta.json
# ./report/audio_files_v5/mayanksain-561a522e/webapp-asquire-mox-na_mayanksain-561a522e_meta-data_na_na.json
# ./report/audio_files_v5/mayanksain-561a522e/webapp-asquire-mox-na_mayanksain-561a522e_meta-data_na_na.meta.json
# ./report/audio_files_v5/richo-f3ef1152/webapp-asquire-mox-na_richo-f3ef1152_meta-data_na_na.json
# ./report/audio_files_v5/richo-f3ef1152/webapp-asquire-mox-na_richo-f3ef1152_meta-data_na_na.meta.json
# ./report/audio_files_v5/niharika-a8738865/webapp-asquire-mox-na_niharika-a8738865_meta-data_na_na.json
# ./report/audio_files_v5/niharika-a8738865/webapp-asquire-mox-na_niharika-a8738865_meta-data_na_na.meta.json
# ./report/audio_files_v5/jinkarakesh-e2fe70ff/webapp-asquire-mox-koi_jinkarakesh-e2fe70ff_meta-data_na_na.json
# ./report/audio_files_v5/jinkarakesh-e2fe70ff/webapp-asquire-mox-koi_jinkarakesh-e2fe70ff_meta-data_na_na.meta.json
# ./report/audio_files_v5/thqnoo-39b65a27/webapp-asquire-mox-na_thqnoo-39b65a27_meta-data_na_na.json
# ./report/audio_files_v5/thqnoo-39b65a27/webapp-asquire-mox-na_thqnoo-39b65a27_meta-data_na_na.meta.json
# ./report/audio_files_v5/sanchari-ece57362/webapp-asquire-mox-na_sanchari-ece57362_meta-data_na_na.json
# ./report/audio_files_v5/sanchari-ece57362/webapp-asquire-mox-na_sanchari-ece57362_meta-data_na_na.meta.json
# ./report/audio_files_v5/mahi-7b9c9b51/webapp-asquire-mox-na_mahi-7b9c9b51_meta-data_na_na.json
# ./report/audio_files_v5/mahi-7b9c9b51/webapp-asquire-mox-na_mahi-7b9c9b51_meta-data_na_na.meta.json
# ./report/audio_files_v5/kira-fc779f36/webapp-asquire-mox-na_kira-fc779f36_meta-data_na_na.json
# ./report/audio_files_v5/kira-fc779f36/webapp-asquire-mox-na_kira-fc779f36_meta-data_na_na.meta.json
# ./report/audio_files_v5/saniya-c3426e28/webapp-asquire-mox-na_saniya-c3426e28_meta-data_na_na.json
# ./report/audio_files_v5/saniya-c3426e28/webapp-asquire-mox-na_saniya-c3426e28_meta-data_na_na.meta.json
# ./report/audio_files_v5/sonamgurjar-bdb0ad0d/webapp-asquire-mox-na_sonamgurjar-bdb0ad0d_meta-data_na_na.json
# ./report/audio_files_v5/sonamgurjar-bdb0ad0d/webapp-asquire-mox-na_sonamgurjar-bdb0ad0d_meta-data_na_na.meta.json
# ./report/audio_files_v5/gourav-c2e94c8d/webapp-asquire-mox-na_gourav-c2e94c8d_meta-data_na_na.json
# ./report/audio_files_v5/gourav-c2e94c8d/webapp-asquire-mox-na_gourav-c2e94c8d_meta-data_na_na.meta.json
# ./report/audio_files_v5/sanna-331c341a/webapp-asquire-mox-na_sanna-331c341a_meta-data_na_na.json
# ./report/audio_files_v5/sanna-331c341a/webapp-asquire-mox-na_sanna-331c341a_meta-data_na_na.meta.json
# ./report/audio_files_v5/ssdhillon-a25f6550/webapp-asquire-mox-na_ssdhillon-a25f6550_meta-data_na_na.json
# ./report/audio_files_v5/ssdhillon-a25f6550/webapp-asquire-mox-na_ssdhillon-a25f6550_meta-data_na_na.meta.json
# ./report/audio_files_v5/poklikayi-d8239c93/webapp-asquire-mox-na_poklikayi-d8239c93_meta-data_na_na.json
# ./report/audio_files_v5/poklikayi-d8239c93/webapp-asquire-mox-na_poklikayi-d8239c93_meta-data_na_na.meta.json
# ./report/audio_files_v5/shishupal-af147853/webapp-asquire-mox-na_shishupal-af147853_meta-data_na_na.json
# ./report/audio_files_v5/shishupal-af147853/webapp-asquire-mox-na_shishupal-af147853_meta-data_na_na.meta.json
# ./report/audio_files_v5/adarsh-d13557e5/webapp-asquire-mox-na_adarsh-d13557e5_meta-data_na_na.json
# ./report/audio_files_v5/adarsh-d13557e5/webapp-asquire-mox-na_adarsh-d13557e5_meta-data_na_na.meta.json
# ./report/audio_files_v5/azra-796ced3b/webapp-asquire-mox-na_azra-796ced3b_meta-data_na_na.json
# ./report/audio_files_v5/azra-796ced3b/webapp-asquire-mox-na_azra-796ced3b_meta-data_na_na.meta.json
# ./report/audio_files_v5/ramgopal-90c7d1d6/webapp-asquire-mox-na_ramgopal-90c7d1d6_meta-data_na_na.json
# ./report/audio_files_v5/ramgopal-90c7d1d6/webapp-asquire-mox-na_ramgopal-90c7d1d6_meta-data_na_na.meta.json
# ./report/audio_files_v5/bani-0395d07a/webapp-asquire-mox-na_bani-0395d07a_meta-data_na_na.json
# ./report/audio_files_v5/bani-0395d07a/webapp-asquire-mox-na_bani-0395d07a_meta-data_na_na.meta.json
# ./report/audio_files_v5/arundhati-c7f7cea4/webapp-asquire-mox-na_arundhati-c7f7cea4_meta-data_na_na.json
# ./report/audio_files_v5/arundhati-c7f7cea4/webapp-asquire-mox-na_arundhati-c7f7cea4_meta-data_na_na.meta.json
# ./report/audio_files_v5/anabiyah-4430ec3c/webapp-asquire-mox-na_anabiyah-4430ec3c_meta-data_na_na.json
# ./report/audio_files_v5/anabiyah-4430ec3c/webapp-asquire-mox-na_anabiyah-4430ec3c_meta-data_na_na.meta.json
# ./report/audio_files_v5/neeraj-68c24d40/webapp-asquire-mox-na_neeraj-68c24d40_meta-data_na_na.json
# ./report/audio_files_v5/neeraj-68c24d40/webapp-asquire-mox-na_neeraj-68c24d40_meta-data_na_na.meta.json
# ./report/audio_files_v5/amitraj-a4abaf74/webapp-asquire-mox-na_amitraj-a4abaf74_meta-data_na_na.json
# ./report/audio_files_v5/amitraj-a4abaf74/webapp-asquire-mox-na_amitraj-a4abaf74_meta-data_na_na.meta.json
# ./report/audio_files_v5/naseema-8464307f/webapp-asquire-mox-na_naseema-8464307f_meta-data_na_na.json
# ./report/audio_files_v5/naseema-8464307f/webapp-asquire-mox-na_naseema-8464307f_meta-data_na_na.meta.json
# ./report/audio_files_v5/kruthikasv-a2ac52c9/webapp-asquire-mox-na_kruthikasv-a2ac52c9_meta-data_na_na.json
# ./report/audio_files_v5/kruthikasv-a2ac52c9/webapp-asquire-mox-na_kruthikasv-a2ac52c9_meta-data_na_na.meta.json
# ./report/audio_files_v5/vicky-b85ee34b/webapp-asquire-mox-na_vicky-b85ee34b_meta-data_na_na.json
# ./report/audio_files_v5/vicky-b85ee34b/webapp-asquire-mox-na_vicky-b85ee34b_meta-data_na_na.meta.json
# ./report/audio_files_v5/sahil-e0bed22c/webapp-asquire-mox-na_sahil-e0bed22c_meta-data_na_na.json
# ./report/audio_files_v5/sahil-e0bed22c/webapp-asquire-mox-na_sahil-e0bed22c_meta-data_na_na.meta.json
# ./report/audio_files_v5/sudhir-51b91c93/webapp-asquire-mox-na_sudhir-51b91c93_meta-data_na_na.json
# ./report/audio_files_v5/sudhir-51b91c93/webapp-asquire-mox-na_sudhir-51b91c93_meta-data_na_na.meta.json
# ./report/audio_files_v5/zarka-5ef0e9ce/webapp-asquire-mox-na_zarka-5ef0e9ce_meta-data_na_na.json
# ./report/audio_files_v5/zarka-5ef0e9ce/webapp-asquire-mox-na_zarka-5ef0e9ce_meta-data_na_na.meta.json
# ./report/audio_files_v5/shubhangikhasnis-f43893dc/webapp-asquire-mox-na_shubhangikhasnis-f43893dc_meta-data_na_na.json
# ./report/audio_files_v5/shubhangikhasnis-f43893dc/webapp-asquire-mox-na_shubhangikhasnis-f43893dc_meta-data_na_na.meta.json
# ./report/audio_files_v5/salib-d9a5299b/webapp-asquire-mox-na_salib-d9a5299b_meta-data_na_na.json
# ./report/audio_files_v5/salib-d9a5299b/webapp-asquire-mox-na_salib-d9a5299b_meta-data_na_na.meta.json
# ./report/audio_files_v5/manjunath-1252bd9c/webapp-asquire-mox-na_manjunath-1252bd9c_meta-data_na_na.json
# ./report/audio_files_v5/manjunath-1252bd9c/webapp-asquire-mox-na_manjunath-1252bd9c_meta-data_na_na.meta.json
# ./report/audio_files_v5/rajesh-7de6bc2c/webapp-asquire-mox-na_rajesh-7de6bc2c_meta-data_na_na.json
# ./report/audio_files_v5/rajesh-7de6bc2c/webapp-asquire-mox-na_rajesh-7de6bc2c_meta-data_na_na.meta.json
# ./report/audio_files_v5/prarthana-39ab5a79/webapp-asquire-mox-na_prarthana-39ab5a79_meta-data_na_na.json
# ./report/audio_files_v5/prarthana-39ab5a79/webapp-asquire-mox-na_prarthana-39ab5a79_meta-data_na_na.meta.json
# ./report/audio_files_v5/adeel-51d76d89/webapp-asquire-mox-na_adeel-51d76d89_meta-data_na_na.json
# ./report/audio_files_v5/adeel-51d76d89/webapp-asquire-mox-na_adeel-51d76d89_meta-data_na_na.meta.json
# ./report/audio_files_v5/bhaskar-ce3fa4d7/webapp-asquire-mox-na_bhaskar-ce3fa4d7_meta-data_na_na.json
# ./report/audio_files_v5/bhaskar-ce3fa4d7/webapp-asquire-mox-na_bhaskar-ce3fa4d7_meta-data_na_na.meta.json
# ./report/audio_files_v5/jibraan-da18bcae/webapp-asquire-mox-na_jibraan-da18bcae_meta-data_na_na.json
# ./report/audio_files_v5/jibraan-da18bcae/webapp-asquire-mox-na_jibraan-da18bcae_meta-data_na_na.meta.json
# ./report/audio_files_v5/sanat-eb05ffdc/webapp-asquire-mox-na_sanat-eb05ffdc_meta-data_na_na.json
# ./report/audio_files_v5/sanat-eb05ffdc/webapp-asquire-mox-na_sanat-eb05ffdc_meta-data_na_na.meta.json
# ./report/audio_files_v5/deepa-4c842704/webapp-asquire-mox-na_deepa-4c842704_meta-data_na_na.json
# ./report/audio_files_v5/deepa-4c842704/webapp-asquire-mox-na_deepa-4c842704_meta-data_na_na.meta.json
# ./report/audio_files_v5/krishna-c75f8cf4/webapp-asquire-mox-na_krishna-c75f8cf4_meta-data_na_na.json
# ./report/audio_files_v5/krishna-c75f8cf4/webapp-asquire-mox-na_krishna-c75f8cf4_meta-data_na_na.meta.json
# ./report/audio_files_v5/nagalakshmis-34cb9d79/webapp-asquire-mox-na_nagalakshmis-34cb9d79_meta-data_na_na.json
# ./report/audio_files_v5/nagalakshmis-34cb9d79/webapp-asquire-mox-na_nagalakshmis-34cb9d79_meta-data_na_na.meta.json
# ./report/audio_files_v5/rm-02a0f969/webapp-asquire-mox-na_rm-02a0f969_meta-data_na_na.json
# ./report/audio_files_v5/rm-02a0f969/webapp-asquire-mox-na_rm-02a0f969_meta-data_na_na.meta.json
# ./report/audio_files_v5/srinivas-b89febe6/webapp-asquire-mox-na_srinivas-b89febe6_meta-data_na_na.json
# ./report/audio_files_v5/srinivas-b89febe6/webapp-asquire-mox-na_srinivas-b89febe6_meta-data_na_na.meta.json
# ./report/audio_files_v5/shivendra-49fd0914/webapp-asquire-mox-na_shivendra-49fd0914_meta-data_na_na.json
# ./report/audio_files_v5/shivendra-49fd0914/webapp-asquire-mox-na_shivendra-49fd0914_meta-data_na_na.meta.json
#                    app_code              sub_id file_class file_xindex score  \
# 0        webapp-asquire-mox      anish-02df6c90      cough           1    NA
# 1        webapp-asquire-mox      anish-02df6c90     breath           0    NA
# 2        webapp-asquire-mox      anish-02df6c90         ss           5    NA
# 3        webapp-asquire-mox      anish-02df6c90        yee           6    NA
# 4     webapp-asquire-mox-na      anish-02df6c90  meta-data          na    na
# ...                     ...                 ...        ...         ...   ...
# 1664     webapp-asquire-mox   srinivas-b89febe6     breath           5    NA
# 1665     webapp-asquire-mox   srinivas-b89febe6         aa           2    NA
# 1666     webapp-asquire-mox  shivendra-49fd0914         aa           4     2
# 1667     webapp-asquire-mox  shivendra-49fd0914     breath           2     0
# 1668  webapp-asquire-mox-na  shivendra-49fd0914  meta-data          na    na
#
#      file_format                                          file_name  \
# 0            wav   webapp-asquire-mox_anish-02df6c90_cough_1_NA.wav
# 1            wav  webapp-asquire-mox_anish-02df6c90_breath_0_NA.wav
# 2            wav      webapp-asquire-mox_anish-02df6c90_ss_5_NA.wav
# 3            wav     webapp-asquire-mox_anish-02df6c90_yee_6_NA.wav
# 4           json  webapp-asquire-mox-na_anish-02df6c90_meta-data...
# ...          ...                                                ...
# 1664         wav  webapp-asquire-mox_srinivas-b89febe6_breath_5_...
# 1665         wav   webapp-asquire-mox_srinivas-b89febe6_aa_2_NA.wav
# 1666         wav   webapp-asquire-mox_shivendra-49fd0914_aa_4_2.wav
# 1667         wav  webapp-asquire-mox_shivendra-49fd0914_breath_2...
# 1668        json  webapp-asquire-mox-na_shivendra-49fd0914_meta-...
#
#                                               file_path  \
# 0     report/audio_files_v5/anish-02df6c90/webapp-as...
# 1     report/audio_files_v5/anish-02df6c90/webapp-as...
# 2     report/audio_files_v5/anish-02df6c90/webapp-as...
# 3     report/audio_files_v5/anish-02df6c90/webapp-as...
# 4     report/audio_files_v5/anish-02df6c90/webapp-as...
# ...                                                 ...
# 1664  report/audio_files_v5/srinivas-b89febe6/webapp...
# 1665  report/audio_files_v5/srinivas-b89febe6/webapp...
# 1666  report/audio_files_v5/shivendra-49fd0914/webap...
# 1667  report/audio_files_v5/shivendra-49fd0914/webap...
# 1668  report/audio_files_v5/shivendra-49fd0914/webap...
#
#                                              file_match anot--file_format  \
# 0          webapp-asquire-mox_anish-02df6c90_cough_1_NA               txt
# 1         webapp-asquire-mox_anish-02df6c90_breath_0_NA               txt
# 2             webapp-asquire-mox_anish-02df6c90_ss_5_NA               txt
# 3            webapp-asquire-mox_anish-02df6c90_yee_6_NA               txt
# 4     webapp-asquire-mox-na_anish-02df6c90_meta-data...         meta.json
# ...                                                 ...               ...
# 1664   webapp-asquire-mox_srinivas-b89febe6_breath_5_NA               txt
# 1665       webapp-asquire-mox_srinivas-b89febe6_aa_2_NA               txt
# 1666       webapp-asquire-mox_shivendra-49fd0914_aa_4_2               txt
# 1667   webapp-asquire-mox_shivendra-49fd0914_breath_2_0               txt
# 1668  webapp-asquire-mox-na_shivendra-49fd0914_meta-...         meta.json
#
#                                         anot--file_name  \
# 0      webapp-asquire-mox_anish-02df6c90_cough_1_NA.txt
# 1     webapp-asquire-mox_anish-02df6c90_breath_0_NA.txt
# 2         webapp-asquire-mox_anish-02df6c90_ss_5_NA.txt
# 3        webapp-asquire-mox_anish-02df6c90_yee_6_NA.txt
# 4     webapp-asquire-mox-na_anish-02df6c90_meta-data...
# ...                                                 ...
# 1664  webapp-asquire-mox_srinivas-b89febe6_breath_5_...
# 1665   webapp-asquire-mox_srinivas-b89febe6_aa_2_NA.txt
# 1666   webapp-asquire-mox_shivendra-49fd0914_aa_4_2.txt
# 1667  webapp-asquire-mox_shivendra-49fd0914_breath_2...
# 1668  webapp-asquire-mox-na_shivendra-49fd0914_meta-...
#
#                                         anot--file_path age height gender  \
# 0     report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 1     report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 2     report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 3     report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 4                                                 False  20    160      m
# ...                                                 ...  ..    ...    ...
# 1664  report/audio_files_v5/srinivas-b89febe6/webapp...  60    172      m
# 1665  report/audio_files_v5/srinivas-b89febe6/webapp...  60    172      m
# 1666  report/audio_files_v5/shivendra-49fd0914/webap...  20    170      m
# 1667  report/audio_files_v5/shivendra-49fd0914/webap...  20    170      m
# 1668                                              False  20    170      m
#
#      weight
# 0        45
# 1        45
# 2        45
# 3        45
# 4        45
# ...     ...
# 1664     85
# 1665     85
# 1666     78
# 1667     78
# 1668     78
#
# [1669 rows x 16 columns]

# %%
asqdata_meta_files.SOURCE_FILES_META_DF
# Out:
#                    app_code              sub_id file_class file_xindex score  \
# 0        webapp-asquire-mox      anish-02df6c90      cough           1    NA
# 1        webapp-asquire-mox      anish-02df6c90     breath           0    NA
# 2        webapp-asquire-mox      anish-02df6c90         ss           5    NA
# 3        webapp-asquire-mox      anish-02df6c90        yee           6    NA
# 4     webapp-asquire-mox-na      anish-02df6c90  meta-data          na    na
# ...                     ...                 ...        ...         ...   ...
# 1664     webapp-asquire-mox   srinivas-b89febe6     breath           5    NA
# 1665     webapp-asquire-mox   srinivas-b89febe6         aa           2    NA
# 1666     webapp-asquire-mox  shivendra-49fd0914         aa           4     2
# 1667     webapp-asquire-mox  shivendra-49fd0914     breath           2     0
# 1668  webapp-asquire-mox-na  shivendra-49fd0914  meta-data          na    na
#
#      file_format                                          file_name  \
# 0            wav   webapp-asquire-mox_anish-02df6c90_cough_1_NA.wav
# 1            wav  webapp-asquire-mox_anish-02df6c90_breath_0_NA.wav
# 2            wav      webapp-asquire-mox_anish-02df6c90_ss_5_NA.wav
# 3            wav     webapp-asquire-mox_anish-02df6c90_yee_6_NA.wav
# 4           json  webapp-asquire-mox-na_anish-02df6c90_meta-data...
# ...          ...                                                ...
# 1664         wav  webapp-asquire-mox_srinivas-b89febe6_breath_5_...
# 1665         wav   webapp-asquire-mox_srinivas-b89febe6_aa_2_NA.wav
# 1666         wav   webapp-asquire-mox_shivendra-49fd0914_aa_4_2.wav
# 1667         wav  webapp-asquire-mox_shivendra-49fd0914_breath_2...
# 1668        json  webapp-asquire-mox-na_shivendra-49fd0914_meta-...
#
#                                               file_path  \
# 0     report/audio_files_v5/anish-02df6c90/webapp-as...
# 1     report/audio_files_v5/anish-02df6c90/webapp-as...
# 2     report/audio_files_v5/anish-02df6c90/webapp-as...
# 3     report/audio_files_v5/anish-02df6c90/webapp-as...
# 4     report/audio_files_v5/anish-02df6c90/webapp-as...
# ...                                                 ...
# 1664  report/audio_files_v5/srinivas-b89febe6/webapp...
# 1665  report/audio_files_v5/srinivas-b89febe6/webapp...
# 1666  report/audio_files_v5/shivendra-49fd0914/webap...
# 1667  report/audio_files_v5/shivendra-49fd0914/webap...
# 1668  report/audio_files_v5/shivendra-49fd0914/webap...
#
#                                              file_match anot--file_format  \
# 0          webapp-asquire-mox_anish-02df6c90_cough_1_NA               txt
# 1         webapp-asquire-mox_anish-02df6c90_breath_0_NA               txt
# 2             webapp-asquire-mox_anish-02df6c90_ss_5_NA               txt
# 3            webapp-asquire-mox_anish-02df6c90_yee_6_NA               txt
# 4     webapp-asquire-mox-na_anish-02df6c90_meta-data...         meta.json
# ...                                                 ...               ...
# 1664   webapp-asquire-mox_srinivas-b89febe6_breath_5_NA               txt
# 1665       webapp-asquire-mox_srinivas-b89febe6_aa_2_NA               txt
# 1666       webapp-asquire-mox_shivendra-49fd0914_aa_4_2               txt
# 1667   webapp-asquire-mox_shivendra-49fd0914_breath_2_0               txt
# 1668  webapp-asquire-mox-na_shivendra-49fd0914_meta-...         meta.json
#
#                                         anot--file_name  \
# 0      webapp-asquire-mox_anish-02df6c90_cough_1_NA.txt
# 1     webapp-asquire-mox_anish-02df6c90_breath_0_NA.txt
# 2         webapp-asquire-mox_anish-02df6c90_ss_5_NA.txt
# 3        webapp-asquire-mox_anish-02df6c90_yee_6_NA.txt
# 4     webapp-asquire-mox-na_anish-02df6c90_meta-data...
# ...                                                 ...
# 1664  webapp-asquire-mox_srinivas-b89febe6_breath_5_...
# 1665   webapp-asquire-mox_srinivas-b89febe6_aa_2_NA.txt
# 1666   webapp-asquire-mox_shivendra-49fd0914_aa_4_2.txt
# 1667  webapp-asquire-mox_shivendra-49fd0914_breath_2...
# 1668  webapp-asquire-mox-na_shivendra-49fd0914_meta-...
#
#                                         anot--file_path age height gender  \
# 0     report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 1     report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 2     report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 3     report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 4                                                 False  20    160      m
# ...                                                 ...  ..    ...    ...
# 1664  report/audio_files_v5/srinivas-b89febe6/webapp...  60    172      m
# 1665  report/audio_files_v5/srinivas-b89febe6/webapp...  60    172      m
# 1666  report/audio_files_v5/shivendra-49fd0914/webap...  20    170      m
# 1667  report/audio_files_v5/shivendra-49fd0914/webap...  20    170      m
# 1668                                              False  20    170      m
#
#      weight
# 0        45
# 1        45
# 2        45
# 3        45
# 4        45
# ...     ...
# 1664     85
# 1665     85
# 1666     78
# 1667     78
# 1668     78
#
# [1669 rows x 16 columns]

# %%
import functools

class AnotDF(DataStaticInfo):
  

    def __init__(self, all_files_src_df: pd.DataFrame) -> None:
        # self.VER = ver

        self.ALL_FILES_DF = all_files_src_df


    def filter_file_df(self, keys: list) -> pd.DataFrame:

        df = self.ALL_FILES_DF.copy()
        filts = [df[self.fkeys['FNAME']].str.contains(k) for k in keys]
        filt = functools.reduce(lambda p, c: p & c, filts)

        return df.loc[filt]
    
    def read_aud_anot(self, finfo: pd.Series):
        df = pd.read_csv(finfo[f"anot--{self.fkeys['FPATH']}"], sep="\t", names=["start", "end", "label"])
        df["line_number"] = range(1, len(df) + 1)
        df["dur"] = df["end"] - df["start"]
        return pd.concat([finfo.to_frame().T]*len(df), ignore_index=True, axis=0).join(df)

    def get_aud_anot_df(self):

        filt = self.ALL_FILES_DF[self.fkeys['FFMT']] == "wav"
        audio_anot_file_df = self.ALL_FILES_DF.loc[filt].copy()

        # return audio_anot_file_df
        aud_anot = [
            self.read_aud_anot(af)
            for _, af in audio_anot_file_df.iterrows()
        ]
        
        audio_anot_df = pd.concat(aud_anot).copy()

        audio_anot_df.to_csv("asq_anotes_df.csv", index=False)

        return audio_anot_df


audio_df = AnotDF(asqdata_meta_files.SOURCE_FILES_META_DF)
aud_df_c = audio_df.get_aud_anot_df(); aud_df_c
# Out:
#               app_code              sub_id file_class file_xindex score  \
# 0   webapp-asquire-mox      anish-02df6c90      cough           1    NA
# 1   webapp-asquire-mox      anish-02df6c90      cough           1    NA
# 2   webapp-asquire-mox      anish-02df6c90      cough           1    NA
# 0   webapp-asquire-mox      anish-02df6c90     breath           0    NA
# 1   webapp-asquire-mox      anish-02df6c90     breath           0    NA
# ..                 ...                 ...        ...         ...   ...
# 1   webapp-asquire-mox  shivendra-49fd0914         aa           4     2
# 0   webapp-asquire-mox  shivendra-49fd0914     breath           2     0
# 1   webapp-asquire-mox  shivendra-49fd0914     breath           2     0
# 2   webapp-asquire-mox  shivendra-49fd0914     breath           2     0
# 3   webapp-asquire-mox  shivendra-49fd0914     breath           2     0
#
#    file_format                                          file_name  \
# 0          wav   webapp-asquire-mox_anish-02df6c90_cough_1_NA.wav
# 1          wav   webapp-asquire-mox_anish-02df6c90_cough_1_NA.wav
# 2          wav   webapp-asquire-mox_anish-02df6c90_cough_1_NA.wav
# 0          wav  webapp-asquire-mox_anish-02df6c90_breath_0_NA.wav
# 1          wav  webapp-asquire-mox_anish-02df6c90_breath_0_NA.wav
# ..         ...                                                ...
# 1          wav   webapp-asquire-mox_shivendra-49fd0914_aa_4_2.wav
# 0          wav  webapp-asquire-mox_shivendra-49fd0914_breath_2...
# 1          wav  webapp-asquire-mox_shivendra-49fd0914_breath_2...
# 2          wav  webapp-asquire-mox_shivendra-49fd0914_breath_2...
# 3          wav  webapp-asquire-mox_shivendra-49fd0914_breath_2...
#
#                                             file_path  \
# 0   report/audio_files_v5/anish-02df6c90/webapp-as...
# 1   report/audio_files_v5/anish-02df6c90/webapp-as...
# 2   report/audio_files_v5/anish-02df6c90/webapp-as...
# 0   report/audio_files_v5/anish-02df6c90/webapp-as...
# 1   report/audio_files_v5/anish-02df6c90/webapp-as...
# ..                                                ...
# 1   report/audio_files_v5/shivendra-49fd0914/webap...
# 0   report/audio_files_v5/shivendra-49fd0914/webap...
# 1   report/audio_files_v5/shivendra-49fd0914/webap...
# 2   report/audio_files_v5/shivendra-49fd0914/webap...
# 3   report/audio_files_v5/shivendra-49fd0914/webap...
#
#                                           file_match anot--file_format  ...  \
# 0       webapp-asquire-mox_anish-02df6c90_cough_1_NA               txt  ...
# 1       webapp-asquire-mox_anish-02df6c90_cough_1_NA               txt  ...
# 2       webapp-asquire-mox_anish-02df6c90_cough_1_NA               txt  ...
# 0      webapp-asquire-mox_anish-02df6c90_breath_0_NA               txt  ...
# 1      webapp-asquire-mox_anish-02df6c90_breath_0_NA               txt  ...
# ..                                               ...               ...  ...
# 1       webapp-asquire-mox_shivendra-49fd0914_aa_4_2               txt  ...
# 0   webapp-asquire-mox_shivendra-49fd0914_breath_2_0               txt  ...
# 1   webapp-asquire-mox_shivendra-49fd0914_breath_2_0               txt  ...
# 2   webapp-asquire-mox_shivendra-49fd0914_breath_2_0               txt  ...
# 3   webapp-asquire-mox_shivendra-49fd0914_breath_2_0               txt  ...
#
#                                       anot--file_path age height gender  \
# 0   report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 1   report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 2   report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 0   report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 1   report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# ..                                                ...  ..    ...    ...
# 1   report/audio_files_v5/shivendra-49fd0914/webap...  20    170      m
# 0   report/audio_files_v5/shivendra-49fd0914/webap...  20    170      m
# 1   report/audio_files_v5/shivendra-49fd0914/webap...  20    170      m
# 2   report/audio_files_v5/shivendra-49fd0914/webap...  20    170      m
# 3   report/audio_files_v5/shivendra-49fd0914/webap...  20    170      m
#
#    weight      start        end  label line_number       dur
# 0      45   1.108703   1.673514     cc           1  0.564811
# 1      45   2.267611   2.769665     cc           2  0.502054
# 2      45   3.321924   3.798876     cc           3  0.476952
# 0      45   2.179427   2.884962     ii           1  0.705535
# 1      45   2.884962   3.450357     xx           2  0.565395
# ..    ...        ...        ...    ...         ...       ...
# 1      78  11.066108  15.921470     aa           2  4.855362
# 0      78   1.155114   2.026605     ii           1  0.871491
# 1      78   2.026605   3.336422     xx           2  1.309817
# 2      78   3.336422   4.481222     ii           3  1.144800
# 3      78   4.481222   5.265049     xx           4  0.783827
#
# [6113 rows x 21 columns]

# %%
aud_df_c["file_class"].value_counts()
# Out:
# breath     1548
# cough      1244
# aa          523
# ee          502
# oo          484
# uu          473
# yee         454
# ss          436
# zz          434
# sent         10
# ~noise~       5
# Name: file_class, dtype: int64

# %%
aud_df_c.describe()
# Out:
#              start          end  line_number          dur
# count  6113.000000  6113.000000  6113.000000  6113.000000
# mean     14.277860    19.951941     3.957141     5.674081
# std      14.425995    16.925300     3.877137     5.785718
# min       0.000000     0.904702     1.000000     0.127330
# 25%       3.162811     7.924119     2.000000     1.123200
# 50%      10.150930    14.795157     3.000000     3.273275
# 75%      20.333300    26.964876     5.000000     8.711493
# max     114.899286   140.095914    34.000000    38.327059

# %%
audio_df.ALL_FILES_DF
# Out:
#                    app_code              sub_id file_class file_xindex score  \
# 0        webapp-asquire-mox      anish-02df6c90      cough           1    NA
# 1        webapp-asquire-mox      anish-02df6c90     breath           0    NA
# 2        webapp-asquire-mox      anish-02df6c90         ss           5    NA
# 3        webapp-asquire-mox      anish-02df6c90        yee           6    NA
# 4     webapp-asquire-mox-na      anish-02df6c90  meta-data          na    na
# ...                     ...                 ...        ...         ...   ...
# 1664     webapp-asquire-mox   srinivas-b89febe6     breath           5    NA
# 1665     webapp-asquire-mox   srinivas-b89febe6         aa           2    NA
# 1666     webapp-asquire-mox  shivendra-49fd0914         aa           4     2
# 1667     webapp-asquire-mox  shivendra-49fd0914     breath           2     0
# 1668  webapp-asquire-mox-na  shivendra-49fd0914  meta-data          na    na
#
#      file_format                                          file_name  \
# 0            wav   webapp-asquire-mox_anish-02df6c90_cough_1_NA.wav
# 1            wav  webapp-asquire-mox_anish-02df6c90_breath_0_NA.wav
# 2            wav      webapp-asquire-mox_anish-02df6c90_ss_5_NA.wav
# 3            wav     webapp-asquire-mox_anish-02df6c90_yee_6_NA.wav
# 4           json  webapp-asquire-mox-na_anish-02df6c90_meta-data...
# ...          ...                                                ...
# 1664         wav  webapp-asquire-mox_srinivas-b89febe6_breath_5_...
# 1665         wav   webapp-asquire-mox_srinivas-b89febe6_aa_2_NA.wav
# 1666         wav   webapp-asquire-mox_shivendra-49fd0914_aa_4_2.wav
# 1667         wav  webapp-asquire-mox_shivendra-49fd0914_breath_2...
# 1668        json  webapp-asquire-mox-na_shivendra-49fd0914_meta-...
#
#                                               file_path  \
# 0     report/audio_files_v5/anish-02df6c90/webapp-as...
# 1     report/audio_files_v5/anish-02df6c90/webapp-as...
# 2     report/audio_files_v5/anish-02df6c90/webapp-as...
# 3     report/audio_files_v5/anish-02df6c90/webapp-as...
# 4     report/audio_files_v5/anish-02df6c90/webapp-as...
# ...                                                 ...
# 1664  report/audio_files_v5/srinivas-b89febe6/webapp...
# 1665  report/audio_files_v5/srinivas-b89febe6/webapp...
# 1666  report/audio_files_v5/shivendra-49fd0914/webap...
# 1667  report/audio_files_v5/shivendra-49fd0914/webap...
# 1668  report/audio_files_v5/shivendra-49fd0914/webap...
#
#                                              file_match anot--file_format  \
# 0          webapp-asquire-mox_anish-02df6c90_cough_1_NA               txt
# 1         webapp-asquire-mox_anish-02df6c90_breath_0_NA               txt
# 2             webapp-asquire-mox_anish-02df6c90_ss_5_NA               txt
# 3            webapp-asquire-mox_anish-02df6c90_yee_6_NA               txt
# 4     webapp-asquire-mox-na_anish-02df6c90_meta-data...         meta.json
# ...                                                 ...               ...
# 1664   webapp-asquire-mox_srinivas-b89febe6_breath_5_NA               txt
# 1665       webapp-asquire-mox_srinivas-b89febe6_aa_2_NA               txt
# 1666       webapp-asquire-mox_shivendra-49fd0914_aa_4_2               txt
# 1667   webapp-asquire-mox_shivendra-49fd0914_breath_2_0               txt
# 1668  webapp-asquire-mox-na_shivendra-49fd0914_meta-...         meta.json
#
#                                         anot--file_name  \
# 0      webapp-asquire-mox_anish-02df6c90_cough_1_NA.txt
# 1     webapp-asquire-mox_anish-02df6c90_breath_0_NA.txt
# 2         webapp-asquire-mox_anish-02df6c90_ss_5_NA.txt
# 3        webapp-asquire-mox_anish-02df6c90_yee_6_NA.txt
# 4     webapp-asquire-mox-na_anish-02df6c90_meta-data...
# ...                                                 ...
# 1664  webapp-asquire-mox_srinivas-b89febe6_breath_5_...
# 1665   webapp-asquire-mox_srinivas-b89febe6_aa_2_NA.txt
# 1666   webapp-asquire-mox_shivendra-49fd0914_aa_4_2.txt
# 1667  webapp-asquire-mox_shivendra-49fd0914_breath_2...
# 1668  webapp-asquire-mox-na_shivendra-49fd0914_meta-...
#
#                                         anot--file_path age height gender  \
# 0     report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 1     report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 2     report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 3     report/audio_files_v5/anish-02df6c90/webapp-as...  20    160      m
# 4                                                 False  20    160      m
# ...                                                 ...  ..    ...    ...
# 1664  report/audio_files_v5/srinivas-b89febe6/webapp...  60    172      m
# 1665  report/audio_files_v5/srinivas-b89febe6/webapp...  60    172      m
# 1666  report/audio_files_v5/shivendra-49fd0914/webap...  20    170      m
# 1667  report/audio_files_v5/shivendra-49fd0914/webap...  20    170      m
# 1668                                              False  20    170      m
#
#      weight
# 0        45
# 1        45
# 2        45
# 3        45
# 4        45
# ...     ...
# 1664     85
# 1665     85
# 1666     78
# 1667     78
# 1668     78
#
# [1669 rows x 16 columns]

# %%
asqdata_meta_files.SOURCE_FILES_META_DF.columns.tolist()
# Out:
# ['app_code',
#  'sub_id',
#  'file_class',
#  'file_xindex',
#  'score',
#  'file_format',
#  'file_name',
#  'file_path',
#  'file_match',
#  'anot--file_format',
#  'anot--file_name',
#  'anot--file_path',
#  'age',
#  'height',
#  'gender',
#  'weight']

# %%
filt = asqdata_meta_files.SOURCE_FILES_META_DF["file_class"] == "undefined"
asqdata_meta_files.SOURCE_FILES_META_DF[filt]
# Out:
# Empty DataFrame
# Columns: [app_code, sub_id, file_class, file_xindex, score, file_format, file_name, file_path, file_match, anot--file_format, anot--file_name, anot--file_path, age, height, gender, weight]
# Index: []

# %%
import librosa
import numpy as np
import soundfile as sf

# %%
from functools import reduce

class FinalProcessDataFiles(DataStaticInfo):

    merge_cols = [
    # 'app_code',
    'sub_id',

    'age',
    'weight',
    'height',
    'gender',
    # 'score',
    ]


    drop_cols = ["file_format", "file_name", "file_class", "file_xindex", "file_match"]


    SOURCE_FILES_DF: pd.DataFrame
    FCLASS_DF_LIST: list 
    MASTER_DATA_DF: pd.DataFrame
    MASTER_DATA_EXPORT_PATH: str

    def __init__(self, all_src_file_df: pd.DataFrame, export_path: str) -> None:
        self.SOURCE_FILES_DF = all_src_file_df
        self.MASTER_DATA_EXPORT_PATH = export_path

        self.MASTER_DATA_DF = self.merge_fclass_dfs()

    AUDIO_EXPORT_FOLDER = f"{REPORT_FOLDER}/audio_files_v4"

    def merge_audio_files(self,fclass_df: pd.DataFrame):

        subjects = fclass_df[self.fkeys["SID"]].unique()

        merged_fclass_dfs = []
        for sub_id in subjects:

            # test
            # sub_id = "azra-796ced3b"
            # /test


            export_folder = f"{self.AUDIO_EXPORT_FOLDER}/{sub_id}"; mkdir(export_folder)


            filt = fclass_df[self.fkeys["SID"]] == sub_id
            sub_df = fclass_df[filt]

            sub_df = sub_df.sort_values(self.fkeys["FCIDX"])
                
            if len(sub_df) < 1:
                continue


            elif ".wav" in sub_df.iloc[0][self.fkeys["FNAME"]]:

                fname = os.path.splitext(sub_df.iloc[0][self.fkeys["FNAME"]])[0]
                export_fpath = f"{export_folder}/{fname}"

                # if os.path.exists(export_fpath):
                #     continue
                
                extend_duration = 0
                extend_anot_dfs = []
                extended_aud_signal = np.ndarray([])

                for i, file in sub_df.iterrows():

                    data_fpath = file[self.fkeys["FPATH"]]
                    anot_fpath = file[f"anot--{self.fkeys['FPATH']}"]

                    signal = librosa.load(data_fpath, sr=44100)[0]
                    extended_aud_signal = np.append(extended_aud_signal, signal)

                    anot_df = pd.read_csv(anot_fpath, 
                                        names=["start", "end", "label"], 
                                        sep="\t", header=None)

                    # test
                    # sf.write(f"./test_aud_{i}.wav", signal, 44100)
                    # anot_df.to_csv(f"./test_anot_{i}.txt", index=False, header=False, sep="\t")
                    # /test

                    # UPDATE ANNOTATION TIME STAMPS
                    anot_df["start"] +=  extend_duration
                    anot_df["end"] += extend_duration

                    # UPDATE DURATION AFTER EXTENDING SIGNAL
                    extend_duration += (signal.shape[0] / 44100)

                    # ANOTATION DATAFRAMES
                    extend_anot_dfs.append(anot_df)

                extended_aud_signal = librosa.util.normalize(extended_aud_signal)
                extended_anot_df = pd.concat(extend_anot_dfs)
                
                

                sf.write(f"{export_fpath}.wav", extended_aud_signal, 44100)
                extended_anot_df.to_csv(f"{export_fpath}.txt", index=False, header=False, sep="\t")

            else:
                fname = (sub_df.iloc[0][self.fkeys["FNAME"]])
                export_fpath = f"{export_folder}/{fname}"

                shutil.copy(sub_df.iloc[0][self.fkeys["FPATH"]], f"{export_fpath}")
            
                

            merged_fclass_dfs.append(sub_df.head(1))

            # test
            # break

        return pd.concat(merged_fclass_dfs, axis=1) if len(merged_fclass_dfs) > 0 else fclass_df

    def seperate_fclass(self):

        fclass_DFs = []
        fclasses = self.SOURCE_FILES_DF[self.fkeys["FCLASS"]].unique()

        print(fclasses)
        for fclass in fclasses[:]:

            filt = self.SOURCE_FILES_DF[self.fkeys["FCLASS"]] == fclass
            fclass_df = self.SOURCE_FILES_DF[filt]

            # if len(fclass_df) > 0:
            #     print("processing: ", fclass,  end=" ")
            #     fclass_df =  self.merge_audio_files(fclass_df)
            #     print("done")
            

            fclass_df.columns = fclass_df.columns.str.replace("file", f"{fclass}--file")

            fclass_DFs.append(fclass_df)

            #test
            # break

        return fclass_DFs
    


    def merge_fclass_dfs(self):

        fclass_DFs = self.seperate_fclass()
        

        df_merged = reduce(lambda  left, right: pd.merge(left, right, on=self.merge_cols, how='outer'), fclass_DFs)

        df_cols = list(df_merged.columns.delete(df_merged.columns.str.contains("|".join(self.drop_cols))))

        df_merged = df_merged[df_cols]

        df_merged = df_merged.fillna(False)
        df_merged = df_merged.replace(False, "-")

        df_merged.sort_values(["gender", "age"], inplace=True)

        df_merged.reset_index(inplace=True)
        # df_merged.drop(columns=["index"], inplace=True)
        df_merged.index.name = "index"

        # df_merged = df_merged[self.col_order]

        # print(list(df_merged.columns))

        rm_cols = df_merged.columns.str.contains("|".join(["app_code", "score"]))

        df_merged = df_merged.drop(columns=df_merged.columns[rm_cols])
        df_merged.to_csv(self.MASTER_DATA_EXPORT_PATH, index=True)

        return df_merged

export_path = f"{REPORT_FOLDER}/asqcorpus_muster.csv"
pnoidata_final_process = FinalProcessDataFiles(asqdata_meta_files.SOURCE_FILES_META_DF, export_path)
# pnoidata_final_process.seperate_fclass()

# pnoidata_final_process.SOURCE_FILES_DF

pnoidata_final_process.MASTER_DATA_DF
# Out:
# ['cough' 'breath' 'ss' 'yee' 'meta-data' 'uu' 'zz' 'aa' 'ee' 'oo' 'sent'
#  '~noise~']
# /tmp/ipykernel_573043/3894237193.py:152: FutureWarning: Passing 'suffixes' which cause duplicate columns {'score_x', 'app_code_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_merged = reduce(lambda  left, right: pd.merge(left, right, on=self.merge_cols, how='outer'), fclass_DFs)
#        index                 sub_id  \
# index
# 0        162   sonamgurjar-bdb0ad0d
# 1          6     jayasurya-99f989e3
# 2        101  aditisatvika-dd09b820
# 3         50         sheen-3d38047e
# 4        133          neha-d4225d24
# ...      ...                    ...
# 198      103        harisk-6f82d610
# 199       47        arhaam-350fc3e6
# 200      120        ravisk-cd186836
# 201      192      srinivas-b89febe6
# 202       20     cooldudeo-060466fb
#
#                                         cough--file_path  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...
# 1      report/audio_files_v5/jayasurya-99f989e3/webap...
# 2      report/audio_files_v5/aditisatvika-dd09b820/we...
# 3      report/audio_files_v5/sheen-3d38047e/webapp-as...
# 4      report/audio_files_v5/neha-d4225d24/webapp-asq...
# ...                                                  ...
# 198    report/audio_files_v5/harisk-6f82d610/webapp-a...
# 199    report/audio_files_v5/arhaam-350fc3e6/webapp-a...
# 200    report/audio_files_v5/ravisk-cd186836/webapp-a...
# 201    report/audio_files_v5/srinivas-b89febe6/webapp...
# 202    report/audio_files_v5/cooldudeo-060466fb/webap...
#
#                                   anot--cough--file_path age height gender  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...  12    137      f
# 1      report/audio_files_v5/jayasurya-99f989e3/webap...  13    150      f
# 2      report/audio_files_v5/aditisatvika-dd09b820/we...  16    170      f
# 3      report/audio_files_v5/sheen-3d38047e/webapp-as...  17    160      f
# 4      report/audio_files_v5/neha-d4225d24/webapp-asq...  17    150      f
# ...                                                  ...  ..    ...    ...
# 198    report/audio_files_v5/harisk-6f82d610/webapp-a...  58    175      m
# 199    report/audio_files_v5/arhaam-350fc3e6/webapp-a...   6    114      m
# 200    report/audio_files_v5/ravisk-cd186836/webapp-a...  60    177      m
# 201    report/audio_files_v5/srinivas-b89febe6/webapp...  60    172      m
# 202    report/audio_files_v5/cooldudeo-060466fb/webap...  16    132      o
#
#       weight                                  breath--file_path  \
# index
# 0         18  report/audio_files_v5/sonamgurjar-bdb0ad0d/web...
# 1         35  report/audio_files_v5/jayasurya-99f989e3/webap...
# 2         40                                                  -
# 3         58  report/audio_files_v5/sheen-3d38047e/webapp-as...
# 4         41  report/audio_files_v5/neha-d4225d24/webapp-asq...
# ...      ...                                                ...
# 198       88  report/audio_files_v5/harisk-6f82d610/webapp-a...
# 199       30  report/audio_files_v5/arhaam-350fc3e6/webapp-a...
# 200       83  report/audio_files_v5/ravisk-cd186836/webapp-a...
# 201       85  report/audio_files_v5/srinivas-b89febe6/webapp...
# 202      102  report/audio_files_v5/cooldudeo-060466fb/webap...
#
#                                  anot--breath--file_path  ...  \
# index                                                     ...
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...  ...
# 1      report/audio_files_v5/jayasurya-99f989e3/webap...  ...
# 2                                                      -  ...
# 3      report/audio_files_v5/sheen-3d38047e/webapp-as...  ...
# 4      report/audio_files_v5/neha-d4225d24/webapp-asq...  ...
# ...                                                  ...  ...
# 198    report/audio_files_v5/harisk-6f82d610/webapp-a...  ...
# 199    report/audio_files_v5/arhaam-350fc3e6/webapp-a...  ...
# 200    report/audio_files_v5/ravisk-cd186836/webapp-a...  ...
# 201    report/audio_files_v5/srinivas-b89febe6/webapp...  ...
# 202    report/audio_files_v5/cooldudeo-060466fb/webap...  ...
#
#                                            aa--file_path  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...
# 1      report/audio_files_v5/jayasurya-99f989e3/webap...
# 2      report/audio_files_v5/aditisatvika-dd09b820/we...
# 3      report/audio_files_v5/sheen-3d38047e/webapp-as...
# 4      report/audio_files_v5/neha-d4225d24/webapp-asq...
# ...                                                  ...
# 198    report/audio_files_v5/harisk-6f82d610/webapp-a...
# 199    report/audio_files_v5/arhaam-350fc3e6/webapp-a...
# 200    report/audio_files_v5/ravisk-cd186836/webapp-a...
# 201    report/audio_files_v5/srinivas-b89febe6/webapp...
# 202    report/audio_files_v5/cooldudeo-060466fb/webap...
#
#                                      anot--aa--file_path  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...
# 1      report/audio_files_v5/jayasurya-99f989e3/webap...
# 2      report/audio_files_v5/aditisatvika-dd09b820/we...
# 3      report/audio_files_v5/sheen-3d38047e/webapp-as...
# 4      report/audio_files_v5/neha-d4225d24/webapp-asq...
# ...                                                  ...
# 198    report/audio_files_v5/harisk-6f82d610/webapp-a...
# 199    report/audio_files_v5/arhaam-350fc3e6/webapp-a...
# 200    report/audio_files_v5/ravisk-cd186836/webapp-a...
# 201    report/audio_files_v5/srinivas-b89febe6/webapp...
# 202    report/audio_files_v5/cooldudeo-060466fb/webap...
#
#                                            ee--file_path  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...
# 1      report/audio_files_v5/jayasurya-99f989e3/webap...
# 2      report/audio_files_v5/aditisatvika-dd09b820/we...
# 3      report/audio_files_v5/sheen-3d38047e/webapp-as...
# 4      report/audio_files_v5/neha-d4225d24/webapp-asq...
# ...                                                  ...
# 198    report/audio_files_v5/harisk-6f82d610/webapp-a...
# 199    report/audio_files_v5/arhaam-350fc3e6/webapp-a...
# 200    report/audio_files_v5/ravisk-cd186836/webapp-a...
# 201    report/audio_files_v5/srinivas-b89febe6/webapp...
# 202                                                    -
#
#                                      anot--ee--file_path  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...
# 1      report/audio_files_v5/jayasurya-99f989e3/webap...
# 2      report/audio_files_v5/aditisatvika-dd09b820/we...
# 3      report/audio_files_v5/sheen-3d38047e/webapp-as...
# 4      report/audio_files_v5/neha-d4225d24/webapp-asq...
# ...                                                  ...
# 198    report/audio_files_v5/harisk-6f82d610/webapp-a...
# 199    report/audio_files_v5/arhaam-350fc3e6/webapp-a...
# 200    report/audio_files_v5/ravisk-cd186836/webapp-a...
# 201    report/audio_files_v5/srinivas-b89febe6/webapp...
# 202                                                    -
#
#                                            oo--file_path  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...
# 1      report/audio_files_v5/jayasurya-99f989e3/webap...
# 2      report/audio_files_v5/aditisatvika-dd09b820/we...
# 3      report/audio_files_v5/sheen-3d38047e/webapp-as...
# 4      report/audio_files_v5/neha-d4225d24/webapp-asq...
# ...                                                  ...
# 198    report/audio_files_v5/harisk-6f82d610/webapp-a...
# 199                                                    -
# 200    report/audio_files_v5/ravisk-cd186836/webapp-a...
# 201    report/audio_files_v5/srinivas-b89febe6/webapp...
# 202                                                    -
#
#                                      anot--oo--file_path sent--file_path  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...               -
# 1      report/audio_files_v5/jayasurya-99f989e3/webap...               -
# 2      report/audio_files_v5/aditisatvika-dd09b820/we...               -
# 3      report/audio_files_v5/sheen-3d38047e/webapp-as...               -
# 4      report/audio_files_v5/neha-d4225d24/webapp-asq...               -
# ...                                                  ...             ...
# 198    report/audio_files_v5/harisk-6f82d610/webapp-a...               -
# 199                                                    -               -
# 200    report/audio_files_v5/ravisk-cd186836/webapp-a...               -
# 201    report/audio_files_v5/srinivas-b89febe6/webapp...               -
# 202                                                    -               -
#
#       anot--sent--file_path ~noise~--file_path anot--~noise~--file_path
# index
# 0                         -                  -                        -
# 1                         -                  -                        -
# 2                         -                  -                        -
# 3                         -                  -                        -
# 4                         -                  -                        -
# ...                     ...                ...                      ...
# 198                       -                  -                        -
# 199                       -                  -                        -
# 200                       -                  -                        -
# 201                       -                  -                        -
# 202                       -                  -                        -
#
# [203 rows x 30 columns]

# %%
pnoidata_final_process.MASTER_DATA_DF.columns.tolist()
# Out:
# ['index',
#  'sub_id',
#  'cough--file_path',
#  'anot--cough--file_path',
#  'age',
#  'height',
#  'gender',
#  'weight',
#  'breath--file_path',
#  'anot--breath--file_path',
#  'ss--file_path',
#  'anot--ss--file_path',
#  'yee--file_path',
#  'anot--yee--file_path',
#  'meta-data--file_path',
#  'anot--meta-data--file_path',
#  'uu--file_path',
#  'anot--uu--file_path',
#  'zz--file_path',
#  'anot--zz--file_path',
#  'aa--file_path',
#  'anot--aa--file_path',
#  'ee--file_path',
#  'anot--ee--file_path',
#  'oo--file_path',
#  'anot--oo--file_path',
#  'sent--file_path',
#  'anot--sent--file_path',
#  '~noise~--file_path',
#  'anot--~noise~--file_path']

# %%
pnoidata_final_process.seperate_fclass()[1]['sub_id'].value_counts()
# Out:
# ['cough' 'breath' 'ss' 'yee' 'meta-data' 'uu' 'zz' 'aa' 'ee' 'oo' 'sent'
#  '~noise~']
# anish-02df6c90              1
# takemi-bcc845d0             1
# arjundeori-b1524a19         1
# dkumar-2377e2ca             1
# amishasinha-94b8bf22        1
#                            ..
# karthiksvasisht-e7d9c436    1
# aryan-7638ca98              1
# tony-3dc3d463               1
# wajiha-0a4be51c             1
# shivendra-49fd0914          1
# Name: sub_id, Length: 170, dtype: int64

# %%
pnoidata_final_process.MASTER_DATA_DF[pnoidata_final_process.MASTER_DATA_DF["sub_id"] == "sonamgurjar-bdb0ad0d"]
# Out:
#        index                sub_id  \
# index
# 0        162  sonamgurjar-bdb0ad0d
#
#                                         cough--file_path  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...
#
#                                   anot--cough--file_path age height gender  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...  12    137      f
#
#       weight                                  breath--file_path  \
# index
# 0         18  report/audio_files_v5/sonamgurjar-bdb0ad0d/web...
#
#                                  anot--breath--file_path  ...  \
# index                                                     ...
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...  ...
#
#                                            aa--file_path  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...
#
#                                      anot--aa--file_path  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...
#
#                                            ee--file_path  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...
#
#                                      anot--ee--file_path  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...
#
#                                            oo--file_path  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...
#
#                                      anot--oo--file_path sent--file_path  \
# index
# 0      report/audio_files_v5/sonamgurjar-bdb0ad0d/web...               -
#
#       anot--sent--file_path ~noise~--file_path anot--~noise~--file_path
# index
# 0                         -                  -                        -
#
# [1 rows x 30 columns]

# %%
pnoidata_final_process.MASTER_DATA_DF.columns.to_list()
# Out:
# ['index',
#  'sub_id',
#  'cough--file_path',
#  'anot--cough--file_path',
#  'age',
#  'height',
#  'gender',
#  'weight',
#  'breath--file_path',
#  'anot--breath--file_path',
#  'ss--file_path',
#  'anot--ss--file_path',
#  'yee--file_path',
#  'anot--yee--file_path',
#  'meta-data--file_path',
#  'anot--meta-data--file_path',
#  'uu--file_path',
#  'anot--uu--file_path',
#  'zz--file_path',
#  'anot--zz--file_path',
#  'aa--file_path',
#  'anot--aa--file_path',
#  'ee--file_path',
#  'anot--ee--file_path',
#  'oo--file_path',
#  'anot--oo--file_path',
#  'sent--file_path',
#  'anot--sent--file_path',
#  '~noise~--file_path',
#  'anot--~noise~--file_path']

# %%
pnoidata_files = DataExtractFiles(DATA_PATH, ver="*")
asqdata_source_files = DataSourceFiles(pnoidata_files.ALL_FILES_DF)
pnoidata_pft_files = ProcessPFTFiles(asqdata_source_files.SOURCE_FILES_DF)
asqdata_meta_files = ProcessMETAFiles(pnoidata_pft_files.SOURCE_FILES_PFT_DF)

export_path = f"{REPORT_FOLDER}/pnoicorpus_muster.csv"
pnoidata_final_process = FinalProcessDataFiles(asqdata_meta_files.SOURCE_FILES_META_DF, export_path)

pnoidata_final_process.MASTER_DATA_DF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/jeevan/Desktop/Asquire/DATA_ANNOTATED/ASQUIRE_DATA-SCRIPT/asquire-etl/asq-dataset_v4.ipynb Cell 28 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/jeevan/Desktop/Asquire/DATA_ANNOTATED/ASQUIRE_DATA-SCRIPT/asquire-etl/asq-dataset_v4.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> pnoidata_files = DataExtractFiles(DATA_PATH, ver="*")
#       <a href='vscode-notebook-cell:/home/jeevan/Desktop/Asquire/DATA_ANNOTATED/ASQUIRE_DATA-SCRIPT/asquire-etl/asq-dataset_v4.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> asqdata_source_files = DataSourceFiles(pnoidata_files.ALL_FILES_DF)
# ----> <a href='vscode-notebook-cell:/home/jeevan/Desktop/Asquire/DATA_ANNOTATED/ASQUIRE_DATA-SCRIPT/asquire-etl/asq-dataset_v4.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> pnoidata_pft_files = ProcessPFTFiles(asqdata_source_files.SOURCE_FILES_DF)
#       <a href='vscode-notebook-cell:/home/jeevan/Desktop/Asquire/DATA_ANNOTATED/ASQUIRE_DATA-SCRIPT/asquire-etl/asq-dataset_v4.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a> asqdata_meta_files = ProcessMETAFiles(pnoidata_pft_files.SOURCE_FILES_PFT_DF)
#       <a href='vscode-notebook-cell:/home/jeevan/Desktop/Asquire/DATA_ANNOTATED/ASQUIRE_DATA-SCRIPT/asquire-etl/asq-dataset_v4.ipynb#X35sZmlsZQ%3D%3D?line=5'>6</a> export_path = f"{REPORT_FOLDER}/pnoicorpus_muster.csv"
#
# NameError: name 'ProcessPFTFiles' is not defined
